# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonDozhdikov/politpredict/blob/main/2_20_political_systems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =============================================================================
# БЛОК 1: УЛУЧШЕННЫЙ ЭКСПЕРИМЕНТ С MADDPG (300 ЭПОХ, ГОДОВОЙ ШАГ)
# =============================================================================

import time
import random
import numpy as np
import pandas as pd
from collections import deque, namedtuple
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pickle
import warnings
import json
import requests
from datetime import datetime, timedelta
warnings.filterwarnings("ignore")

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical
import torch.multiprocessing as mp
from torch.utils.tensorboard import SummaryWriter

# Увеличено количество эпох до 300
CONFIG = {
    'start_year': 2017,
    'train_end_year': 2024,
    'sim_start_year': 2025,
    'sim_end_year': 2075,
    'steps_per_year': 1,  # Годовой шаг
    'num_episodes': 300,  # Увеличено до 300
    'top_countries': 20,
    'observation_total_size': 12,
    'observation_in_size': 12,
    'action_size': 45,
    'hidden_dim': 128,
    'lr_actor': 3e-4,
    'lr_critic': 3e-4,
    'gamma': 0.95,
    'tau': 0.02,
    'buffer_size': int(1e5),
    'batch_size': 128,
    'update_every': 5,
    'epsilon_start': 1.0,
    'epsilon_end': 0.01,
    'epsilon_decay': 0.995, # Слегка уменьшено для более медленного убывания epsilon
    'clip_epsilon': 0.2,
    'gae_lambda': 0.95,
    'ppo_epochs': 3,
    'entropy_coef': 0.01,
    'max_grad_norm': 0.5,
    'device': torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    'save_dir': 'experiment_results_maddpg_improved_300ep',
    'data_dir': 'data'
}

os.makedirs(CONFIG['save_dir'], exist_ok=True)
os.makedirs(CONFIG['data_dir'], exist_ok=True)

def fetch_world_bank_data(indicator, country_code, start_year, end_year):
    base_url = "http://api.worldbank.org/v2/country"
    url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json&per_page=100"

    try:
        response = requests.get(url, timeout=10)
        data = response.json()
        if len(data) > 1:
            return {item['date']: item['value'] for item in data[1] if item['value'] is not None}
        else:
            return {}
    except Exception as e:
        print(f"Ошибка при загрузке данных для {country_code}, {indicator}: {e}")
        return {}

def load_real_historical_data():
    print("Загрузка реальных исторических данных...")

    countries = {
        "United States": "US", "China": "CN", "Japan": "JP", "Germany": "DE", "India": "IN",
        "United Kingdom": "GB", "France": "FR", "Italy": "IT", "Brazil": "BR", "Canada": "CA",
        "South Korea": "KR", "Russia": "RU", "Australia": "AU", "Spain": "ES", "Mexico": "MX",
        "Indonesia": "ID", "Netherlands": "NL", "Saudi Arabia": "SA", "Turkey": "TR", "Switzerland": "CH"
    }

    indicators = {
        'gdp_growth': 'NY.GDP.MKTP.KD.ZG', 'unemployment': 'SL.UEM.TOTL.ZS', 'inflation': 'FP.CPI.TOTL.ZG',
        'aging_index': 'SP.POP.65UP.TO.ZS', 'migration_net': 'SM.POP.NETM', 'gini_coefficient': 'SI.POV.GINI',
        'corruption_index': 'CC.EST', 'political_stability': 'PV.EST', 'innovation_index': 'GB.XPD.RSDV.GD.ZS',
        'environmental_footprint': 'EN.ATM.CO2E.PC', 'education_index': 'SE.TER.ENRR', 'press_freedom': 'EN.PUB.FREX'
    }

    data = {}

    for country_name, country_code in countries.items():
        print(f"Загрузка данных для {country_name}...")
        country_data = {}

        for indicator_name, indicator_code in indicators.items():
            indicator_data = fetch_world_bank_data(indicator_code, country_code, CONFIG['start_year'], CONFIG['train_end_year'])
            country_data[indicator_name] = indicator_data

        years = list(range(CONFIG['start_year'], CONFIG['train_end_year'] + 1))
        country_array = []

        for year in years:
            year_str = str(year)
            row = []
            for indicator_name in indicators.keys():
                value = country_data[indicator_name].get(year_str, np.nan)
                row.append(value if value is not None else np.nan)
            country_array.append(row)

        country_array = np.array(country_array)
        if len(country_array) > 0:
            df = pd.DataFrame(country_array, columns=list(indicators.keys()))
            df = df.fillna(method='ffill').fillna(method='bfill').fillna(0)
            data[country_name] = df.values
        else:
            data[country_name] = np.zeros((CONFIG['train_end_year'] - CONFIG['start_year'] + 1, len(indicators)))

    print("Реальные данные успешно загружены.")
    return data, list(countries.keys())

def generate_synthetic_data(historical_data, countries):
    print("Генерация синтетических данных...")
    synthetic_data = {}

    for country in countries:
        if country in historical_data and len(historical_data[country]) > 0:
            last_data = historical_data[country][-1]
        else:
            last_data = np.random.randn(CONFIG['observation_total_size']) * 0.1

        sim_years = CONFIG['sim_end_year'] - CONFIG['sim_start_year'] + 1
        country_data = []

        for _ in range(sim_years):
            noise = np.random.randn(len(last_data)) * 0.02  # Увеличен шум для разнообразия
            new_data = last_data + noise
            country_data.append(new_data)
            last_data = new_data

        synthetic_data[country] = np.array(country_data)

    print("Синтетические данные сгенерированы.")
    return synthetic_data

def load_historical_data():
    try:
        real_data, countries = load_real_historical_data()
    except Exception as e:
        print(f"Не удалось загрузить реальные данные: {e}")
        print("Использование синтетических данных...")
        countries = [
            "United States", "China", "Japan", "Germany", "India", "United Kingdom",
            "France", "Italy", "Brazil", "Canada", "South Korea", "Russia", "Australia",
            "Spain", "Mexico", "Indonesia", "Netherlands", "Saudi Arabia", "Turkey", "Switzerland"
        ]

        np.random.seed(42)
        real_data = {}

        for country in countries:
            years = CONFIG['train_end_year'] - CONFIG['start_year'] + 1
            country_data = np.random.randn(years, CONFIG['observation_total_size']) * 0.1
            real_data[country] = country_data

    synthetic_data = generate_synthetic_data(real_data, countries)
    return real_data, synthetic_data, countries

class CountrySystem:
    def __init__(self, name, initial_state):
        self.name = name
        self.state = initial_state.copy()
        self.internal_state = self._initialize_internal_state()
        self.stage = "I. Конструктивная адаптация"
        self.history = []
        self.crisis_history = []
        self.stage_transitions = []
        self.step_count = 0
        self.year = CONFIG['sim_start_year']

    def _initialize_internal_state(self):
        return np.array([
            0.8, 1.0, 0.7, 0.75, 0.6, 0.5, 0.2, 0.8, 0.3, 0.5, 0.7, 0.6
        ])

    def get_observation_total(self):
        return self.state

    def get_observation_in(self):
        return self.internal_state

    def apply_action(self, action):
        reward = 0
        crisis_event = None

        self._update_internal_state(action)
        self._update_external_state(action)

        crisis_event = self._check_for_crisis()
        if crisis_event:
            self.crisis_history.append({
                'step': self.step_count, 'year': self.year, 'crisis': crisis_event
            })
            reward -= 50  # Уменьшен штраф за кризис

        new_stage = self._check_stage_transition()
        if new_stage != self.stage:
            self.stage_transitions.append({
                'step': self.step_count, 'year': self.year,
                'from_stage': self.stage, 'to_stage': new_stage
            })
            self.stage = new_stage
            reward += self._get_stage_reward(new_stage)

        reward += self._calculate_stability_reward()

        self.step_count += 1
        self.year += 1

        self.history.append({
            'step': self.step_count, 'state': self.state.copy(), 'internal_state': self.internal_state.copy(),
            'stage': self.stage, 'year': self.year
        })

        return reward, crisis_event is not None

    def _update_internal_state(self, action):
        action_effects = np.zeros_like(self.internal_state)

        if action == 0:  # Повышение налогов
            action_effects[0] -= 0.02; action_effects[2] -= 0.01; action_effects[9] -= 0.01
        elif action == 1:  # Снижение налогов
            action_effects[0] += 0.01; action_effects[2] += 0.01; action_effects[9] += 0.02
        elif action == 2:  # Увеличение социальных расходов
            action_effects[4] += 0.03; action_effects[10] += 0.02; action_effects[9] += 0.01
        elif action == 3:  # Сокращение социальных расходов
            action_effects[4] -= 0.02; action_effects[10] -= 0.01; action_effects[9] -= 0.01
        elif action == 4:  # Реформа пенсионной системы
            action_effects[4] += 0.02; action_effects[1] += 0.02
        elif action == 5:  # Реформа здравоохранения
            action_effects[0] += 0.01; action_effects[10] += 0.01
        elif action == 6:  # Инвестиции в образование и науку
            action_effects[5] += 0.03; action_effects[7] += 0.02
        elif action == 7:  # Поддержка инноваций и стартапов
            action_effects[5] += 0.04; action_effects[11] += 0.03
        elif action == 8:  # Ужесточение миграционной политики
            action_effects[4] -= 0.01; action_effects[10] -= 0.01
        elif action == 9:  # Либерализация миграционной политики
            action_effects[4] += 0.02; action_effects[10] += 0.01
        elif action == 10: # Проведение амнистии для мигрантов
            action_effects[4] += 0.01; action_effects[10] += 0.02
        elif action == 11: # Усиление полицейского контроля
            action_effects[0] -= 0.01; action_effects[9] -= 0.02
        elif action == 12: # Снижение репрессий, декриминализация
            action_effects[0] += 0.02; action_effects[9] += 0.01
        elif action == 13: # Проведение выборов (честных, свободных)
            action_effects[0] += 0.03; action_effects[7] += 0.03
        elif action == 14: # Фальсификация выборов
            action_effects[0] -= 0.03; action_effects[7] -= 0.02
        elif action == 15: # Роспуск парламента
            action_effects[0] -= 0.02; action_effects[8] += 0.03
        elif action == 16: # Распуск оппозиционных партий
            action_effects[0] -= 0.03; action_effects[7] -= 0.02
        elif action == 17: # Преследование оппозиционеров
            action_effects[0] -= 0.02; action_effects[8] += 0.02
        elif action == 18: # Амнистия политзаключенных
            action_effects[0] += 0.01; action_effects[10] += 0.01
        elif action == 19: # Реформа судебной системы
            action_effects[0] += 0.02; action_effects[11] += 0.01
        elif action == 20: # Укрепление независимости судов
            action_effects[0] += 0.03; action_effects[7] += 0.02
        elif action == 21: # Подавление свободы слова
            action_effects[0] -= 0.03; action_effects[7] -= 0.02
        elif action == 22: # Поддержка свободы слова
            action_effects[0] += 0.03; action_effects[7] += 0.02
        elif action == 23: # Введение цензуры
            action_effects[0] -= 0.02; action_effects[8] += 0.02
        elif action == 24: # Поддержка СМИ
            action_effects[0] += 0.02; action_effects[7] += 0.01
        elif action == 25: # Проведение референдума
            action_effects[0] += 0.01; action_effects[7] += 0.01
        elif action == 26: # Реформа конституции
            action_effects[11] += 0.03; action_effects[5] -= 0.01
        elif action == 27: # Увеличение числа чиновников
            action_effects[1] -= 0.01; action_effects[8] += 0.01
        elif action == 28: # Сокращение бюрократии
            action_effects[1] += 0.02; action_effects[11] += 0.01
        elif action == 29: # Борьба с коррупцией (эффективная)
            action_effects[0] += 0.03; action_effects[10] += 0.02
        elif action == 30: # Имитация борьбы с коррупцией
            action_effects[0] -= 0.01; action_effects[10] -= 0.01
        elif action == 31: # Заключение торгового соглашения
            action_effects[3] += 0.01; action_effects[11] += 0.01
        elif action == 32: # Введение торговых пошлин/санкций
            action_effects[3] -= 0.01; action_effects[9] -= 0.01
        elif action == 33: # Поддержка экспорта
            action_effects[3] += 0.02; action_effects[11] += 0.01
        elif action == 34: # Поддержка импорта
            action_effects[3] += 0.01; action_effects[5] -= 0.01
        elif action == 35: # Заключение военного альянса
            action_effects[9] -= 0.02; action_effects[8] += 0.01
        elif action == 36: # Выход из военного альянса
            action_effects[9] += 0.01; action_effects[11] += 0.01
        elif action == 37: # Начало переговоров
            action_effects[0] += 0.01; action_effects[3] += 0.01
        elif action == 38: # Прекращение переговоров
            action_effects[0] -= 0.01; action_effects[3] -= 0.01
        elif action == 39: # Ведение войны (наступательной)
            action_effects[9] -= 0.03; action_effects[8] += 0.03
        elif action == 40: # Ведение войны (оборонительной)
            action_effects[9] -= 0.02; action_effects[10] -= 0.01
        elif action == 41: # Отправка миротворцев
            action_effects[0] += 0.01; action_effects[3] += 0.01
        elif action == 42: # Принятие беженцев
            action_effects[4] += 0.02; action_effects[10] += 0.01
        elif action == 43: # Отказ от беженцев
            action_effects[4] -= 0.01; action_effects[10] -= 0.01
        elif action == 44: # Мирная экспансия
            action_effects[5] += 0.02; action_effects[11] += 0.02

        self.internal_state = np.clip(self.internal_state + action_effects, 0.0, 1.0)

    def _update_external_state(self, action):
        noise = np.random.normal(0, 0.02, len(self.state))  # Увеличен шум
        self.state = self.state + noise

        if action == 0:
            self.state[0] -= 0.05; self.state[1] += 0.1
        elif action == 2:
            self.state[4] += 0.05; self.state[6] -= 0.03
        elif action == 6:
            self.state[8] += 0.02
        elif action == 7:
            self.state[8] += 0.03
        elif action == 39:
            self.state[0] -= 0.2; self.state[1] += 0.3; self.state[2] += 0.2

    def _check_for_crisis(self):
        crisis_probability = 0.0

        # Базовая вероятность кризиса
        crisis_probability += 0.05

        # Кризисы первого бугра (перепроизводство элиты)
        if self.internal_state[4] < 0.4 and self.state[5] > 0.6:
            crisis_probability += 0.15

        # Кризисы второго бугра (молодые мигранты)
        if self.state[4] > 0.8 and self.internal_state[10] < 0.5:
            crisis_probability += 0.12

        # Общая нестабильность
        if self.internal_state[0] < 0.4 and self.internal_state[2] < 0.5:
            crisis_probability += 0.18

        # Экономический кризис
        if self.state[0] < -1.0 or self.state[1] > 12.0:
            crisis_probability += 0.25

        if np.random.random() < crisis_probability:
            crises = ["Политический переворот", "Экономический кризис", "Социальные волнения",
                     "Военный конфликт", "Экологическая катастрофа", "Финансовый крах",
                     "Пандемия", "Технологическая катастрофа"]
            return np.random.choice(crises)

        return None

    def _check_stage_transition(self):
        if (self.internal_state[0] > 0.75 and self.internal_state[2] > 0.75 and
            self.internal_state[10] > 0.75 and self.internal_state[4] > 0.65):
            return "Точка Превосходства"

        elif (self.internal_state[5] > 0.65 and self.internal_state[7] < 0.35 and
              self.internal_state[1] < 0.45):
            return "Точка Плато (Застой)"

        elif (self.internal_state[6] > 0.75 and self.internal_state[9] < 0.25 and
              self.internal_state[8] > 0.65):
            return "Точка Перенапряжения"

        elif (self.internal_state[10] < 0.25 and self.internal_state[0] < 0.25 and
              self.internal_state[7] < 0.15):
            return "Точка Гибели/Перезапуска"

        if self.internal_state[5] > 0.55 and self.internal_state[7] < 0.45:
            return "III. Деструктивная экспансия"
        elif self.internal_state[5] < 0.45 and self.internal_state[7] > 0.55:
            return "I. Конструктивная адаптация"
        elif self.internal_state[5] > 0.45 and self.internal_state[7] > 0.45:
            return "II. Конструктивная экспансия"
        else:
            return "IV. Деструктивная адаптация (кризис)"

    def _get_stage_reward(self, stage):
        rewards = {
            "Точка Превосходства": 80,      # Уменьшена награда
            "I. Конструктивная адаптация": 40,
            "II. Конструктивная экспансия": 40,
            "Точка Плато (Застой)": -5,
            "III. Деструктивная экспансия": -30,
            "Точка Перенапряжения": -60,
            "IV. Деструктивная адаптация (кризис)": -120,
            "Точка Гибели/Перезапуска": -800  # Уменьшен штраф
        }
        return rewards.get(stage, 0)

    def _calculate_stability_reward(self):
        stability_reward = 0
        balance = abs(self.internal_state[5] - 0.5)
        stability_reward += (1 - balance) * 5  # Уменьшена награда
        stability_reward += self.internal_state[0] * 3
        stability_reward -= self.internal_state[6] * 5
        stability_reward += self.internal_state[4] * 2
        stability_reward -= self.internal_state[8] * 3
        return stability_reward

class MADDPGActor(nn.Module):
    def __init__(self, obs_dim, action_dim, hidden_dim=CONFIG['hidden_dim']):
        super(MADDPGActor, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_dim, hidden_dim), nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim), nn.ReLU(),
            nn.Linear(hidden_dim, action_dim), nn.Softmax(dim=-1)
        )

    def forward(self, obs):
        return self.net(obs)

class MADDPGCritic(nn.Module):
    def __init__(self, obs_dim, action_dim, num_agents, hidden_dim=CONFIG['hidden_dim']):
        super(MADDPGCritic, self).__init__()
        self.num_agents = num_agents
        total_obs_dim = obs_dim * num_agents
        total_action_dim = action_dim * num_agents

        self.net = nn.Sequential(
            nn.Linear(total_obs_dim + total_action_dim, hidden_dim), nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim), nn.ReLU(),
            nn.Linear(hidden_dim, 1)
        )

    def forward(self, obs, actions):
        obs_flat = torch.cat(obs, dim=-1)
        actions_flat = torch.cat(actions, dim=-1)
        x = torch.cat([obs_flat, actions_flat], dim=-1)
        return self.net(x)

class MADDPGAgent:
    def __init__(self, obs_total_dim, obs_in_dim, action_dim, agent_id, num_agents):
        self.agent_id = agent_id
        self.action_dim = action_dim
        self.obs_total_dim = obs_total_dim
        self.obs_in_dim = obs_in_dim
        self.num_agents = num_agents

        self.actor = MADDPGActor(obs_total_dim + obs_in_dim, action_dim).to(CONFIG['device'])
        self.actor_target = MADDPGActor(obs_total_dim + obs_in_dim, action_dim).to(CONFIG['device'])
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=CONFIG['lr_actor'])

        self.critic = MADDPGCritic(obs_total_dim + obs_in_dim, action_dim, num_agents).to(CONFIG['device'])
        self.critic_target = MADDPGCritic(obs_total_dim + obs_in_dim, action_dim, num_agents).to(CONFIG['device'])
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=CONFIG['lr_critic'])

        self.hard_update(self.actor_target, self.actor)
        self.hard_update(self.critic_target, self.critic)

        self.memory = deque(maxlen=CONFIG['buffer_size'])
        self.epsilon = CONFIG['epsilon_start']
        self.experience = namedtuple("Experience",
                                   field_names=["state", "action", "reward", "next_state", "done"])

    def hard_update(self, target, source):
        for target_param, param in zip(target.parameters(), source.parameters()):
            target_param.data.copy_(param.data)

    def soft_update(self, target, source, tau=CONFIG['tau']):
        for target_param, param in zip(target.parameters(), source.parameters()):
            target_param.data.copy_(target_param.data * (1.0 - tau) + param.data * tau)

    def act(self, obs_total, obs_in, noise=True):
        obs = torch.FloatTensor(np.concatenate([obs_total, obs_in])).unsqueeze(0).to(CONFIG['device'])
        action_probs = self.actor(obs)

        if noise and random.random() < self.epsilon:
            action = random.choice(range(self.action_dim))
        else:
            action = torch.argmax(action_probs).item()

        return action

    def remember(self, state, action, reward, next_state, done):
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)

    def replay(self, agents):
        if len(self.memory) < CONFIG['batch_size']:
            return

        experiences = random.sample(self.memory, k=CONFIG['batch_size'])

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(CONFIG['device'])
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(CONFIG['device'])
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(CONFIG['device'])
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(CONFIG['device'])
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(CONFIG['device'])

        obs_total_dim = self.obs_total_dim
        obs_in_dim = self.obs_in_dim

        states_list = []
        next_states_list = []
        actions_list = []

        for i in range(self.num_agents):
            start_total = i * (obs_total_dim + obs_in_dim)
            end_total = start_total + obs_total_dim
            start_in = end_total
            end_in = start_in + obs_in_dim

            states_list.append(states[:, start_total:end_in])
            next_states_list.append(next_states[:, start_total:end_in])
            actions_list.append(actions[:, i])

        next_actions = []
        for i, agent in enumerate(agents):
            next_action_probs = agent.actor_target(next_states_list[i])
            next_actions.append(torch.argmax(next_action_probs, dim=-1, keepdim=True))

        next_actions_onehot = [F.one_hot(na.squeeze(-1), num_classes=self.action_dim).float() for na in next_actions]

        Q_targets_next = self.critic_target(next_states_list, next_actions_onehot).squeeze(-1)
        Q_targets = rewards[:, self.agent_id] + (CONFIG['gamma'] * Q_targets_next * (1 - dones[:, self.agent_id]))

        actions_onehot = [F.one_hot(a, num_classes=self.action_dim).float() for a in actions_list]
        Q_expected = self.critic(states_list, actions_onehot).squeeze(-1)

        critic_loss = F.mse_loss(Q_expected, Q_targets.detach())

        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.critic.parameters(), CONFIG['max_grad_norm'])
        self.critic_optimizer.step()

        actions_pred = self.actor(states_list[self.agent_id])
        actions_pred_onehot = F.gumbel_softmax(torch.log(actions_pred + 1e-8), hard=True)

        actor_loss = -self.critic(states_list,
                                 [F.one_hot(a, num_classes=self.action_dim).float() if i != self.agent_id
                                  else actions_pred_onehot for i, a in enumerate(actions_list)]).mean()

        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.actor.parameters(), CONFIG['max_grad_norm'])
        self.actor_optimizer.step()

        self.soft_update(self.actor_target, self.actor)
        self.soft_update(self.critic_target, self.critic)

        self.epsilon = max(CONFIG['epsilon_end'], self.epsilon * CONFIG['epsilon_decay'])

def run_maddpg_experiment():
    print("Запуск улучшенного эксперимента с MADDPG агентами (300 эпох)...")

    real_data, synthetic_data, countries = load_historical_data()

    country_systems = {}
    for country in countries:
        if country in real_data and len(real_data[country]) > 0:
            initial_state = real_data[country][-1]
        else:
            initial_state = synthetic_data[country][0] if len(synthetic_data[country]) > 0 else np.zeros(CONFIG['observation_total_size'])
        country_systems[country] = CountrySystem(country, initial_state)

    agents = {}
    obs_total_dim = CONFIG['observation_total_size']
    obs_in_dim = CONFIG['observation_in_size']
    action_dim = CONFIG['action_size']
    num_agents = len(countries)

    for i, country in enumerate(countries):
        agents[country] = MADDPGAgent(obs_total_dim, obs_in_dim, action_dim, i, num_agents)

    all_rewards = []
    all_crisis_histories = {country: [] for country in countries}
    all_stage_transitions = {country: [] for country in countries}
    final_states = {}

    timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
    writer = SummaryWriter(f'runs/MADDPG_experiment_improved_300ep_{timestamp}')

    experiment_start_time = time.time()

    # Для более удобного мониторинга при 300 эпохах, выводим прогресс каждые 30 эпох
    progress_interval = 30

    for episode in range(CONFIG['num_episodes']):
        episode_start_time = time.time()
        print(f"Эпизод {episode + 1}/{CONFIG['num_episodes']}")

        for country in countries:
            if country in real_data and len(real_data[country]) > 0:
                initial_state = real_data[country][-1]
            else:
                initial_state = synthetic_data[country][0] if len(synthetic_data[country]) > 0 else np.zeros(CONFIG['observation_total_size'])
            country_systems[country] = CountrySystem(country, initial_state)

        episode_rewards = []
        episode_crisis_count = 0

        total_steps = CONFIG['sim_end_year'] - CONFIG['sim_start_year'] + 1
        episode_step_start_time = time.time()

        for step in range(total_steps):
            observations_total = []
            observations_in = []
            actions = []

            for country in countries:
                obs_total = country_systems[country].get_observation_total()
                obs_in = country_systems[country].get_observation_in()
                observations_total.append(obs_total)
                observations_in.append(obs_in)

            for country in countries:
                action = agents[country].act(observations_total[countries.index(country)],
                                           observations_in[countries.index(country)])
                actions.append(action)

            rewards = []
            for i, country in enumerate(countries):
                reward, crisis_occurred = country_systems[country].apply_action(actions[i])
                rewards.append(reward)
                if crisis_occurred:
                    episode_crisis_count += 1

            episode_rewards.append(sum(rewards))

            if step % CONFIG['update_every'] == 0:
                for country in countries:
                    # Формируем состояние для всех агентов
                    state_all = np.concatenate([np.concatenate([observations_total[j], observations_in[j]])
                                              for j in range(num_agents)])
                    next_observations_total = []
                    next_observations_in = []
                    for country_name in countries:
                        obs_total = country_systems[country_name].get_observation_total()
                        obs_in = country_systems[country_name].get_observation_in()
                        next_observations_total.append(obs_total)
                        next_observations_in.append(obs_in)

                    next_state_all = np.concatenate([np.concatenate([next_observations_total[j], next_observations_in[j]])
                                                   for j in range(num_agents)])

                    for i, country_name in enumerate(countries):
                        agents[country_name].remember(
                            state_all,
                            actions,
                            rewards,
                            next_state_all,
                            [step == total_steps - 1] * num_agents
                        )

            if step % CONFIG['update_every'] == 0:
                for country in countries:
                    agents[country].replay(list(agents.values()))

            # Обновлено: вывод прогресса реже при 300 эпохах
            if step > 0 and step % max(1, total_steps // 3) == 0: # Примерно 3 точки отчета за эпоху
                elapsed_step_time = time.time() - episode_step_start_time
                steps_remaining = total_steps - step
                estimated_time_remaining = (elapsed_step_time / step) * steps_remaining if step > 0 else 0
                print(f"  Шаг {step}/{total_steps} ({step/total_steps*100:.1f}%) | "
                      f"Прошло: {timedelta(seconds=int(elapsed_step_time))} | "
                      f"Осталось: {timedelta(seconds=int(estimated_time_remaining))}")

        avg_reward = np.mean(episode_rewards)
        all_rewards.append(avg_reward)

        for country in countries:
            all_crisis_histories[country].extend(country_systems[country].crisis_history)
            all_stage_transitions[country].extend(country_systems[country].stage_transitions)

        writer.add_scalar('Average Reward', avg_reward, episode)
        writer.add_scalar('Crisis Count', episode_crisis_count, episode)

        episode_elapsed_time = time.time() - episode_start_time
        episodes_remaining = CONFIG['num_episodes'] - episode - 1
        experiment_elapsed_time = time.time() - experiment_start_time
        estimated_total_experiment_time = (experiment_elapsed_time / (episode + 1)) * CONFIG['num_episodes']
        estimated_experiment_remaining = estimated_total_experiment_time - experiment_elapsed_time

        print(f"  Средняя награда: {avg_reward:.2f}, Кризисов: {episode_crisis_count}")
        print(f"  Время эпизода: {timedelta(seconds=int(episode_elapsed_time))}")
        print(f"  Прошло эксперимента: {timedelta(seconds=int(experiment_elapsed_time))} | "
              f"Осталось: {timedelta(seconds=int(estimated_experiment_remaining))}")

        # Добавлено: Промежуточное сохранение каждые progress_interval эпох
        if (episode + 1) % progress_interval == 0:
            intermediate_results = {
                'all_rewards': all_rewards,
                'all_crisis_histories': all_crisis_histories,
                'all_stage_transitions': all_stage_transitions,
                'countries': countries,
                'current_episode': episode + 1
            }
            with open(f"{CONFIG['save_dir']}/MADDPG_intermediate_results_ep_{episode+1}.pkl", 'wb') as f:
                pickle.dump(intermediate_results, f)
            print(f"  Промежуточные результаты сохранены на эпохе {episode+1}")

    for country in countries:
        final_states[country] = country_systems[country].state

    writer.close()

    results = {
        'final_states': final_states,
        'all_rewards': all_rewards,
        'all_crisis_histories': all_crisis_histories,
        'all_stage_transitions': all_stage_transitions,
        'countries': countries
    }

    with open(f"{CONFIG['save_dir']}/MADDPG_results.pkl", 'wb') as f:
        pickle.dump(results, f)

    experiment_total_time = time.time() - experiment_start_time
    print(f"Эксперимент с MADDPG завершен.")
    print(f"Общее время эксперимента: {timedelta(seconds=int(experiment_total_time))}")
    return results

def plot_maddpg_results(results):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))

    # График наград по эпизодам
    axes[0, 0].plot(results['all_rewards'], label='MADDPG', alpha=0.7, linewidth=2, color='blue')
    axes[0, 0].set_xlabel('Эпизод')
    axes[0, 0].set_ylabel('Средняя награда')
    axes[0, 0].set_title('Средние награды MADDPG по эпизодам')
    axes[0, 0].legend()
    axes[0, 0].grid(True)

    # Скользящее среднее наград
    window_size = 10
    rewards_smooth = pd.Series(results['all_rewards']).rolling(window=window_size).mean()
    axes[0, 1].plot(rewards_smooth, label='MADDPG (скользящее среднее)', alpha=0.7, linewidth=2, color='green')
    axes[0, 1].set_xlabel('Эпизод')
    axes[0, 1].set_ylabel('Средняя награда')
    axes[0, 1].set_title(f'Скользящее среднее наград (окно={window_size})')
    axes[0, 1].legend()
    axes[0, 1].grid(True)

    # Распределение кризисов по странам
    crisis_counts = [len(results['all_crisis_histories'][country]) for country in results['countries']]
    axes[1, 0].bar(range(len(results['countries'])), crisis_counts, color='red', alpha=0.7)
    axes[1, 0].set_xlabel('Страны')
    axes[1, 0].set_ylabel('Количество кризисов')
    axes[1, 0].set_title('Распределение кризисов по странам')
    axes[1, 0].set_xticks(range(len(results['countries'])))
    axes[1, 0].set_xticklabels(results['countries'], rotation=45, ha='right')
    axes[1, 0].grid(True)

    # Распределение переходов по странам
    transition_counts = [len(results['all_stage_transitions'][country]) for country in results['countries']]
    axes[1, 1].bar(range(len(results['countries'])), transition_counts, color='orange', alpha=0.7)
    axes[1, 1].set_xlabel('Страны')
    axes[1, 1].set_ylabel('Количество переходов')
    axes[1, 1].set_title('Распределение переходов по странам')
    axes[1, 1].set_xticks(range(len(results['countries'])))
    axes[1, 1].set_xticklabels(results['countries'], rotation=45, ha='right')
    axes[1, 1].grid(True)

    plt.tight_layout()
    plt.savefig(f"{CONFIG['save_dir']}/MADDPG_detailed_analysis.png", dpi=300, bbox_inches='tight')
    plt.show()

def print_maddpg_summary(results):
    print("\n=== ИТОГОВАЯ СВОДКА ДЛЯ MADDPG ===")

    avg_reward = np.mean(results['all_rewards'])
    std_reward = np.std(results['all_rewards'])
    print(f"Средняя награда по всем эпизодам: {avg_reward:.2f} ± {std_reward:.2f}")

    total_crises = sum(len(crises) for crises in results['all_crisis_histories'].values())
    print(f"Общее количество кризисов: {total_crises}")

    total_transitions = sum(len(transitions) for transitions in results['all_stage_transitions'].values())
    print(f"Общее количество переходов между стадиями: {total_transitions}")

    crisis_types = []
    for crises in results['all_crisis_histories'].values():
        for crisis in crises:
            crisis_types.append(crisis['crisis'])

    if crisis_types:
        from collections import Counter
        crisis_counter = Counter(crisis_types)
        print("\nТоп-5 типов кризисов по частоте:")
        for crisis, count in crisis_counter.most_common(5):
            print(f"  {crisis}: {count} раз")

    print("\nРаспределение кризисов по странам:")
    country_crises = [(country, len(crises)) for country, crises in results['all_crisis_histories'].items()]
    country_crises.sort(key=lambda x: x[1], reverse=True)
    for country, count in country_crises:
        print(f"  {country}: {count} кризисов")

    with open(f"{CONFIG['save_dir']}/MADDPG_detailed_summary.txt", 'w', encoding='utf-8') as f:
        f.write("ИТОГОВАЯ СВОДКА ДЛЯ MADDPG\n")
        f.write("=" * 50 + "\n")
        f.write(f"Средняя награда по всем эпизодам: {avg_reward:.2f} ± {std_reward:.2f}\n")
        f.write(f"Общее количество кризисов: {total_crises}\n")
        f.write(f"Общее количество переходов между стадиями: {total_transitions}\n\n")

        f.write("Топ-5 типов кризисов по частоте:\n")
        if crisis_types:
            crisis_counter = Counter(crisis_types)
            for crisis, count in crisis_counter.most_common(5):
                f.write(f"  {crisis}: {count} раз\n")

        f.write("\nИстория кризисов по странам:\n")
        for country, crises in results['all_crisis_histories'].items():
            if crises:
                f.write(f"\n{country} ({len(crises)} кризисов):\n")
                for crisis in crises:
                    f.write(f"  Год {crisis['year']}: {crisis['crisis']}\n")

        f.write("\n\nИстория переходов между стадиями по странам:\n")
        for country, transitions in results['all_stage_transitions'].items():
            if transitions:
                f.write(f"\n{country} ({len(transitions)} переходов):\n")
                for transition in transitions:
                    f.write(f"  Год {transition['year']}: "
                           f"{transition['from_stage']} -> {transition['to_stage']}\n")

def prevent_runtime_disconnect():
    print("Для предотвращения отключения среды введите '555' и нажмите Enter:")
    while True:
        user_input = input()
        if user_input == "555":
            print("Среда защищена от отключения.")
            break
        else:
            print("Неверный код. Пожалуйста, введите '555':")

if __name__ == "__main__":
    prevent_runtime_disconnect()
    print("\n" + "=" * 50)
    print("ЗАПУСК УЛУЧШЕННОГО MADDPG ЭКСПЕРИМЕНТА (300 ЭПОХ)")
    print("=" * 50)
    maddpg_results = run_maddpg_experiment()
    plot_maddpg_results(maddpg_results)
    print_maddpg_summary(maddpg_results)
# Out:
# Для предотвращения отключения среды введите '555' и нажмите Enter:
# 555
# Среда защищена от отключения.
#
# ==================================================
# ЗАПУСК УЛУЧШЕННОГО MADDPG ЭКСПЕРИМЕНТА (300 ЭПОХ)
# ==================================================
# Запуск улучшенного эксперимента с MADDPG агентами (300 эпох)...
# Загрузка реальных исторических данных...
# Загрузка данных для United States...
# Загрузка данных для China...
# Загрузка данных для Japan...
# Загрузка данных для Germany...
# Загрузка данных для India...
# Загрузка данных для United Kingdom...
# Загрузка данных для France...
# Загрузка данных для Italy...
# Загрузка данных для Brazil...
# Загрузка данных для Canada...
# Загрузка данных для South Korea...
# Загрузка данных для Russia...
# Загрузка данных для Australia...
# Загрузка данных для Spain...
# Загрузка данных для Mexico...
# Загрузка данных для Indonesia...
# Загрузка данных для Netherlands...
# Загрузка данных для Saudi Arabia...
# Загрузка данных для Turkey...
# Загрузка данных для Switzerland...
# Реальные данные успешно загружены.
# Генерация синтетических данных...
# Синтетические данные сгенерированы.
# Эпизод 1/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 87.30, Кризисов: 59
#   Время эпизода: 0:00:02
#   Прошло эксперимента: 0:00:02 | Осталось: 0:12:09
# Эпизод 2/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 89.42, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:00:07 | Осталось: 0:19:19
# Эпизод 3/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 92.79, Кризисов: 51
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:00:13 | Осталось: 0:22:14
# Эпизод 4/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 96.55, Кризисов: 52
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:00:18 | Осталось: 0:23:12
# Эпизод 5/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 84.16, Кризисов: 63
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:00:24 | Осталось: 0:24:10
# Эпизод 6/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 99.12, Кризисов: 53
#   Время эпизода: 0:00:06
#   Прошло эксперимента: 0:00:30 | Осталось: 0:25:06
# Эпизод 7/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 100.04, Кризисов: 48
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:00:36 | Осталось: 0:25:37
# Эпизод 8/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 95.36, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:00:41 | Осталось: 0:25:24
# Эпизод 9/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 92.86, Кризисов: 48
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:00:47 | Осталось: 0:25:30
# Эпизод 10/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 93.31, Кризисов: 52
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:00:52 | Осталось: 0:25:19
# Эпизод 11/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 74.98, Кризисов: 63
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:00:57 | Осталось: 0:25:09
# Эпизод 12/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.56, Кризисов: 59
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:01:02 | Осталось: 0:25:06
# Эпизод 13/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 95.80, Кризисов: 47
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:01:07 | Осталось: 0:24:52
# Эпизод 14/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 83.51, Кризисов: 54
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:01:12 | Осталось: 0:24:50
# Эпизод 15/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.16, Кризисов: 60
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:01:18 | Осталось: 0:24:51
# Эпизод 16/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 96.09, Кризисов: 44
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:01:23 | Осталось: 0:24:45
# Эпизод 17/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 83.77, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:01:28 | Осталось: 0:24:36
# Эпизод 18/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.85, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:01:34 | Осталось: 0:24:38
# Эпизод 19/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 75.91, Кризисов: 61
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:01:39 | Осталось: 0:24:30
# Эпизод 20/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 69.38, Кризисов: 68
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:01:44 | Осталось: 0:24:28
# Эпизод 21/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 101.58, Кризисов: 36
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:01:49 | Осталось: 0:24:18
# Эпизод 22/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 92.15, Кризисов: 45
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:01:54 | Осталось: 0:24:11
# Эпизод 23/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.30, Кризисов: 56
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:01:59 | Осталось: 0:24:01
# Эпизод 24/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 87.28, Кризисов: 51
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:02:04 | Осталось: 0:23:53
# Эпизод 25/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 85.88, Кризисов: 53
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:02:10 | Осталось: 0:23:51
# Эпизод 26/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 76.70, Кризисов: 60
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:02:15 | Осталось: 0:23:46
# Эпизод 27/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 83.73, Кризисов: 53
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:02:20 | Осталось: 0:23:44
# Эпизод 28/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 70.46, Кризисов: 67
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:02:25 | Осталось: 0:23:37
# Эпизод 29/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.55, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:02:31 | Осталось: 0:23:32
# Эпизод 30/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 72.39, Кризисов: 64
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:02:36 | Осталось: 0:23:28
#   Промежуточные результаты сохранены на эпохе 30
# Эпизод 31/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 89.06, Кризисов: 48
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:02:41 | Осталось: 0:23:24
# Эпизод 32/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.28, Кризисов: 58
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:02:46 | Осталось: 0:23:16
# Эпизод 33/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 76.03, Кризисов: 60
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:02:52 | Осталось: 0:23:12
# Эпизод 34/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.72, Кризисов: 56
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:02:57 | Осталось: 0:23:07
# Эпизод 35/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 71.40, Кризисов: 64
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:03:02 | Осталось: 0:23:00
# Эпизод 36/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 73.38, Кризисов: 63
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:03:07 | Осталось: 0:22:56
# Эпизод 37/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 70.54, Кризисов: 66
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:03:13 | Осталось: 0:22:52
# Эпизод 38/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 67.37, Кризисов: 69
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:03:18 | Осталось: 0:22:48
# Эпизод 39/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 93.23, Кризисов: 43
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:03:23 | Осталось: 0:22:41
# Эпизод 40/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 70.96, Кризисов: 66
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:03:28 | Осталось: 0:22:36
# Эпизод 41/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 82.79, Кризисов: 54
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:03:34 | Осталось: 0:22:32
# Эпизод 42/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 76.29, Кризисов: 61
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:03:39 | Осталось: 0:22:29
# Эпизод 43/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.20, Кризисов: 58
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:03:44 | Осталось: 0:22:21
# Эпизод 44/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 67.68, Кризисов: 69
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:03:49 | Осталось: 0:22:16
# Эпизод 45/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 77.71, Кризисов: 59
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:03:54 | Осталось: 0:22:09
# Эпизод 46/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:02 | Осталось: 0:00:01
#   Средняя награда: 76.59, Кризисов: 60
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:03:59 | Осталось: 0:22:02
# Эпизод 47/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 72.75, Кризисов: 64
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:04:05 | Осталось: 0:22:00
# Эпизод 48/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 89.61, Кризисов: 47
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:04:10 | Осталось: 0:21:55
# Эпизод 49/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 70.74, Кризисов: 66
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:04:15 | Осталось: 0:21:50
# Эпизод 50/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 74.99, Кризисов: 62
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:04:20 | Осталось: 0:21:44
# Эпизод 51/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.63, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:04:26 | Осталось: 0:21:40
# Эпизод 52/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 72.95, Кризисов: 64
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:04:31 | Осталось: 0:21:33
# Эпизод 53/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 86.49, Кризисов: 50
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:04:36 | Осталось: 0:21:28
# Эпизод 54/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 87.99, Кризисов: 48
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:04:41 | Осталось: 0:21:21
# Эпизод 55/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.11, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:04:46 | Осталось: 0:21:17
# Эпизод 56/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 87.63, Кризисов: 48
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:04:51 | Осталось: 0:21:11
# Эпизод 57/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 82.76, Кризисов: 53
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:04:56 | Осталось: 0:21:05
# Эпизод 58/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 76.24, Кризисов: 62
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:05:02 | Осталось: 0:21:02
# Эпизод 59/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 75.69, Кризисов: 61
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:05:07 | Осталось: 0:20:56
# Эпизод 60/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 80.10, Кризисов: 56
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:05:13 | Осталось: 0:20:52
#   Промежуточные результаты сохранены на эпохе 60
# Эпизод 61/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.16, Кризисов: 57
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:05:18 | Осталось: 0:20:46
# Эпизод 62/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 70.19, Кризисов: 66
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:05:23 | Осталось: 0:20:40
# Эпизод 63/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 77.33, Кризисов: 59
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:05:28 | Осталось: 0:20:34
# Эпизод 64/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 85.21, Кризисов: 51
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:05:33 | Осталось: 0:20:30
# Эпизод 65/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 86.91, Кризисов: 49
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:05:38 | Осталось: 0:20:25
# Эпизод 66/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:04 | Осталось: 0:00:02
#   Средняя награда: 82.20, Кризисов: 54
#   Время эпизода: 0:00:06
#   Прошло эксперимента: 0:05:45 | Осталось: 0:20:24
# Эпизод 67/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 84.04, Кризисов: 52
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:05:50 | Осталось: 0:20:19
# Эпизод 68/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 68.46, Кризисов: 68
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:05:56 | Осталось: 0:20:16
# Эпизод 69/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 74.36, Кризисов: 62
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:06:01 | Осталось: 0:20:11
# Эпизод 70/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 83.02, Кризисов: 53
#   Время эпизода: 0:00:06
#   Прошло эксперимента: 0:06:08 | Осталось: 0:20:09
# Эпизод 71/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.34, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:06:13 | Осталось: 0:20:05
# Эпизод 72/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.26, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:06:19 | Осталось: 0:20:01
# Эпизод 73/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 83.99, Кризисов: 52
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:06:24 | Осталось: 0:19:56
# Эпизод 74/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 76.09, Кризисов: 60
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:06:30 | Осталось: 0:19:52
# Эпизод 75/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:04 | Осталось: 0:00:02
#   Средняя награда: 93.16, Кризисов: 43
#   Время эпизода: 0:00:06
#   Прошло эксперимента: 0:06:37 | Осталось: 0:19:51
# Эпизод 76/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 73.43, Кризисов: 63
#   Время эпизода: 0:00:06
#   Прошло эксперимента: 0:06:43 | Осталось: 0:19:48
# Эпизод 77/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 84.22, Кризисов: 52
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:06:48 | Осталось: 0:19:42
# Эпизод 78/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 88.16, Кризисов: 48
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:06:53 | Осталось: 0:19:38
# Эпизод 79/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 82.07, Кризисов: 54
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:06:58 | Осталось: 0:19:32
# Эпизод 80/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 85.53, Кризисов: 51
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:07:04 | Осталось: 0:19:28
# Эпизод 81/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.11, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:07:10 | Осталось: 0:19:22
# Эпизод 82/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 66.40, Кризисов: 70
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:07:15 | Осталось: 0:19:17
# Эпизод 83/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 88.23, Кризисов: 48
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:07:20 | Осталось: 0:19:11
# Эпизод 84/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.38, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:07:25 | Осталось: 0:19:06
# Эпизод 85/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 65.47, Кризисов: 71
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:07:31 | Осталось: 0:19:02
# Эпизод 86/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 84.10, Кризисов: 52
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:07:36 | Осталось: 0:18:55
# Эпизод 87/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 70.53, Кризисов: 66
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:07:42 | Осталось: 0:18:51
# Эпизод 88/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.42, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:07:47 | Осталось: 0:18:46
# Эпизод 89/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:04 | Осталось: 0:00:02
#   Средняя награда: 77.32, Кризисов: 59
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:07:53 | Осталось: 0:18:42
# Эпизод 90/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.12, Кризисов: 55
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:07:58 | Осталось: 0:18:36
#   Промежуточные результаты сохранены на эпохе 90
# Эпизод 91/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 83.95, Кризисов: 52
#   Время эпизода: 0:00:06
#   Прошло эксперимента: 0:08:04 | Осталось: 0:18:32
# Эпизод 92/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 67.20, Кризисов: 69
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:08:10 | Осталось: 0:18:27
# Эпизод 93/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 80.04, Кризисов: 56
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:08:15 | Осталось: 0:18:22
# Эпизод 94/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 85.26, Кризисов: 51
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:08:21 | Осталось: 0:18:18
# Эпизод 95/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 91.03, Кризисов: 45
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:08:26 | Осталось: 0:18:13
# Эпизод 96/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:02 | Осталось: 0:00:01
#   Средняя награда: 72.30, Кризисов: 64
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:08:31 | Осталось: 0:18:06
# Эпизод 97/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.23, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:08:36 | Осталось: 0:18:01
# Эпизод 98/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:02 | Осталось: 0:00:01
#   Средняя награда: 74.47, Кризисов: 62
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:08:41 | Осталось: 0:17:55
# Эпизод 99/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 89.05, Кризисов: 47
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:08:47 | Осталось: 0:17:50
# Эпизод 100/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 86.12, Кризисов: 50
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:08:52 | Осталось: 0:17:45
# Эпизод 101/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:04 | Осталось: 0:00:02
#   Средняя награда: 78.26, Кризисов: 58
#   Время эпизода: 0:00:06
#   Прошло эксперимента: 0:08:58 | Осталось: 0:17:41
# Эпизод 102/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 64.49, Кризисов: 72
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:09:04 | Осталось: 0:17:36
# Эпизод 103/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 88.80, Кризисов: 47
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:09:09 | Осталось: 0:17:30
# Эпизод 104/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 82.14, Кризисов: 54
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:09:15 | Осталось: 0:17:26
# Эпизод 105/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 82.15, Кризисов: 54
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:09:20 | Осталось: 0:17:20
# Эпизод 106/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.21, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:09:25 | Осталось: 0:17:15
# Эпизод 107/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 85.16, Кризисов: 51
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:09:30 | Осталось: 0:17:08
# Эпизод 108/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:04 | Осталось: 0:00:02
#   Средняя награда: 64.75, Кризисов: 72
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:09:36 | Осталось: 0:17:04
# Эпизод 109/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 74.21, Кризисов: 62
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:09:41 | Осталось: 0:16:58
# Эпизод 110/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 65.72, Кризисов: 71
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:09:46 | Осталось: 0:16:53
# Эпизод 111/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:02 | Осталось: 0:00:01
#   Средняя награда: 90.06, Кризисов: 46
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:09:51 | Осталось: 0:16:46
# Эпизод 112/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.30, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:09:56 | Осталось: 0:16:41
# Эпизод 113/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 73.44, Кризисов: 63
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:10:01 | Осталось: 0:16:36
# Эпизод 114/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.01, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:10:07 | Осталось: 0:16:30
# Эпизод 115/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 82.05, Кризисов: 54
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:10:12 | Осталось: 0:16:24
# Эпизод 116/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 90.92, Кризисов: 45
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:10:17 | Осталось: 0:16:19
# Эпизод 117/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.23, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:10:23 | Осталось: 0:16:15
# Эпизод 118/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.29, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:10:28 | Осталось: 0:16:09
# Эпизод 119/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 83.53, Кризисов: 53
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:10:34 | Осталось: 0:16:04
# Эпизод 120/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 87.18, Кризисов: 49
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:10:39 | Осталось: 0:15:58
#   Промежуточные результаты сохранены на эпохе 120
# Эпизод 121/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 85.04, Кризисов: 51
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:10:44 | Осталось: 0:15:53
# Эпизод 122/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.20, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:10:50 | Осталось: 0:15:48
# Эпизод 123/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.24, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:10:56 | Осталось: 0:15:44
# Эпизод 124/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 84.30, Кризисов: 52
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:11:01 | Осталось: 0:15:38
# Эпизод 125/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 91.04, Кризисов: 45
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:11:07 | Осталось: 0:15:33
# Эпизод 126/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.23, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:11:12 | Осталось: 0:15:28
# Эпизод 127/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 82.07, Кризисов: 54
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:11:17 | Осталось: 0:15:23
# Эпизод 128/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.27, Кризисов: 55
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:11:22 | Осталось: 0:15:17
# Эпизод 129/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 96.24, Кризисов: 40
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:11:28 | Осталось: 0:15:12
# Эпизод 130/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 82.13, Кризисов: 54
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:11:33 | Осталось: 0:15:07
# Эпизод 131/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.08, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:11:39 | Осталось: 0:15:02
# Эпизод 132/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:02 | Осталось: 0:00:01
#   Средняя награда: 96.87, Кризисов: 39
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:11:44 | Осталось: 0:14:56
# Эпизод 133/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 86.56, Кризисов: 50
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:11:49 | Осталось: 0:14:51
# Эпизод 134/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 74.32, Кризисов: 62
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:11:55 | Осталось: 0:14:46
# Эпизод 135/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 84.19, Кризисов: 52
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:12:01 | Осталось: 0:14:41
# Эпизод 136/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.29, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:12:07 | Осталось: 0:14:36
# Эпизод 137/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 77.52, Кризисов: 59
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:12:11 | Осталось: 0:14:30
# Эпизод 138/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 90.01, Кризисов: 46
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:12:17 | Осталось: 0:14:25
# Эпизод 139/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.46, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:12:22 | Осталось: 0:14:20
# Эпизод 140/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 76.29, Кризисов: 60
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:12:28 | Осталось: 0:14:15
# Эпизод 141/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 84.16, Кризисов: 52
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:12:34 | Осталось: 0:14:10
# Эпизод 142/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:05
#   Шаг 34/51 (66.7%) | Прошло: 0:00:04 | Осталось: 0:00:02
#   Средняя награда: 66.76, Кризисов: 70
#   Время эпизода: 0:00:06
#   Прошло эксперимента: 0:12:40 | Осталось: 0:14:06
# Эпизод 143/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 76.27, Кризисов: 60
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:12:45 | Осталось: 0:14:00
# Эпизод 144/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.38, Кризисов: 58
#   Время эпизода: 0:00:06
#   Прошло эксперимента: 0:12:52 | Осталось: 0:13:56
# Эпизод 145/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 87.17, Кризисов: 49
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:12:57 | Осталось: 0:13:51
# Эпизод 146/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.27, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:13:03 | Осталось: 0:13:46
# Эпизод 147/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.94, Кризисов: 54
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:13:08 | Осталось: 0:13:41
# Эпизод 148/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:04 | Осталось: 0:00:02
#   Средняя награда: 87.02, Кризисов: 49
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:13:14 | Осталось: 0:13:36
# Эпизод 149/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 88.08, Кризисов: 48
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:13:20 | Осталось: 0:13:31
# Эпизод 150/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.31, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:13:25 | Осталось: 0:13:25
#   Промежуточные результаты сохранены на эпохе 150
# Эпизод 151/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.23, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:13:31 | Осталось: 0:13:20
# Эпизод 152/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.46, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:13:36 | Осталось: 0:13:15
# Эпизод 153/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.14, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:13:41 | Осталось: 0:13:09
# Эпизод 154/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 68.27, Кризисов: 68
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:13:47 | Осталось: 0:13:04
# Эпизод 155/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 77.40, Кризисов: 59
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:13:53 | Осталось: 0:12:59
# Эпизод 156/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:04 | Осталось: 0:00:02
#   Средняя награда: 80.11, Кризисов: 56
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:13:58 | Осталось: 0:12:54
# Эпизод 157/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 86.22, Кризисов: 50
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:14:03 | Осталось: 0:12:48
# Эпизод 158/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.38, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:14:09 | Осталось: 0:12:43
# Эпизод 159/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 80.21, Кризисов: 56
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:14:14 | Осталось: 0:12:37
# Эпизод 160/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.20, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:14:20 | Осталось: 0:12:32
# Эпизод 161/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 75.33, Кризисов: 61
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:14:25 | Осталось: 0:12:27
# Эпизод 162/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 80.30, Кризисов: 56
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:14:30 | Осталось: 0:12:21
# Эпизод 163/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.25, Кризисов: 58
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:14:35 | Осталось: 0:12:16
# Эпизод 164/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.16, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:14:41 | Осталось: 0:12:10
# Эпизод 165/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 69.56, Кризисов: 67
#   Время эпизода: 0:00:06
#   Прошло эксперимента: 0:14:47 | Осталось: 0:12:06
# Эпизод 166/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 71.28, Кризисов: 65
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:14:52 | Осталось: 0:12:00
# Эпизод 167/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:04 | Осталось: 0:00:02
#   Средняя награда: 76.22, Кризисов: 60
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:14:57 | Осталось: 0:11:55
# Эпизод 168/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 74.32, Кризисов: 62
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:15:03 | Осталось: 0:11:49
# Эпизод 169/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 80.12, Кризисов: 56
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:15:08 | Осталось: 0:11:44
# Эпизод 170/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.27, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:15:14 | Осталось: 0:11:39
# Эпизод 171/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.04, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:15:19 | Осталось: 0:11:33
# Эпизод 172/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.21, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:15:24 | Осталось: 0:11:28
# Эпизод 173/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 93.11, Кризисов: 43
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:15:30 | Осталось: 0:11:23
# Эпизод 174/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 94.04, Кризисов: 42
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:15:35 | Осталось: 0:11:17
# Эпизод 175/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.38, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:15:41 | Осталось: 0:11:12
# Эпизод 176/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 86.01, Кризисов: 50
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:15:46 | Осталось: 0:11:06
# Эпизод 177/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 90.03, Кризисов: 46
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:15:52 | Осталось: 0:11:01
# Эпизод 178/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 73.40, Кризисов: 63
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:15:57 | Осталось: 0:10:56
# Эпизод 179/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.29, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:16:02 | Осталось: 0:10:50
# Эпизод 180/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.26, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:16:08 | Осталось: 0:10:45
#   Промежуточные результаты сохранены на эпохе 180
# Эпизод 181/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 90.97, Кризисов: 45
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:16:14 | Осталось: 0:10:40
# Эпизод 182/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 86.29, Кризисов: 50
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:16:19 | Осталось: 0:10:35
# Эпизод 183/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 83.06, Кризисов: 53
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:16:24 | Осталось: 0:10:29
# Эпизод 184/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.13, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:16:29 | Осталось: 0:10:23
# Эпизод 185/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 74.29, Кризисов: 62
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:16:34 | Осталось: 0:10:18
# Эпизод 186/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 97.82, Кризисов: 38
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:16:40 | Осталось: 0:10:13
# Эпизод 187/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 84.95, Кризисов: 51
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:16:45 | Осталось: 0:10:07
# Эпизод 188/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 76.49, Кризисов: 60
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:16:51 | Осталось: 0:10:02
# Эпизод 189/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.11, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:16:56 | Осталось: 0:09:57
# Эпизод 190/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 82.21, Кризисов: 54
#   Время эпизода: 0:00:05
# ...
#   Средняя награда: 81.42, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:21:39 | Осталось: 0:05:24
#   Промежуточные результаты сохранены на эпохе 240
# Эпизод 241/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 87.08, Кризисов: 49
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:21:44 | Осталось: 0:05:19
# Эпизод 242/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 72.54, Кризисов: 64
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:21:49 | Осталось: 0:05:13
# Эпизод 243/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 69.33, Кризисов: 67
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:21:54 | Осталось: 0:05:08
# Эпизод 244/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 71.44, Кризисов: 65
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:22:00 | Осталось: 0:05:02
# Эпизод 245/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 83.17, Кризисов: 53
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:22:05 | Осталось: 0:04:57
# Эпизод 246/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 83.04, Кризисов: 53
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:22:10 | Осталось: 0:04:52
# Эпизод 247/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 83.17, Кризисов: 53
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:22:16 | Осталось: 0:04:46
# Эпизод 248/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 75.17, Кризисов: 61
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:22:21 | Осталось: 0:04:41
# Эпизод 249/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 68.61, Кризисов: 68
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:22:26 | Осталось: 0:04:35
# Эпизод 250/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 87.16, Кризисов: 49
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:22:32 | Осталось: 0:04:30
# Эпизод 251/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 82.15, Кризисов: 54
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:22:37 | Осталось: 0:04:25
# Эпизод 252/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 74.26, Кризисов: 62
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:22:43 | Осталось: 0:04:19
# Эпизод 253/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.25, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:22:48 | Осталось: 0:04:14
# Эпизод 254/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 66.55, Кризисов: 70
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:22:54 | Осталось: 0:04:08
# Эпизод 255/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 80.23, Кризисов: 56
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:22:59 | Осталось: 0:04:03
# Эпизод 256/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:02 | Осталось: 0:00:01
#   Средняя награда: 88.09, Кризисов: 48
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:23:04 | Осталось: 0:03:57
# Эпизод 257/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.43, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:23:10 | Осталось: 0:03:52
# Эпизод 258/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 86.97, Кризисов: 49
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:23:15 | Осталось: 0:03:47
# Эпизод 259/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 85.20, Кризисов: 51
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:23:21 | Осталось: 0:03:41
# Эпизод 260/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:02 | Осталось: 0:00:01
#   Средняя награда: 87.47, Кризисов: 49
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:23:25 | Осталось: 0:03:36
# Эпизод 261/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 81.07, Кризисов: 55
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:23:31 | Осталось: 0:03:30
# Эпизод 262/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 71.56, Кризисов: 65
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:23:36 | Осталось: 0:03:25
# Эпизод 263/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 88.11, Кризисов: 48
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:23:42 | Осталось: 0:03:20
# Эпизод 264/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 67.63, Кризисов: 69
#   Время эпизода: 0:00:07
#   Прошло эксперимента: 0:23:49 | Осталось: 0:03:14
# Эпизод 265/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:04 | Осталось: 0:00:02
#   Средняя награда: 87.18, Кризисов: 49
#   Время эпизода: 0:00:06
#   Прошло эксперимента: 0:23:55 | Осталось: 0:03:09
# Эпизод 266/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 89.07, Кризисов: 47
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:23:59 | Осталось: 0:03:04
# Эпизод 267/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.39, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:24:05 | Осталось: 0:02:58
# Эпизод 268/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 74.40, Кризисов: 62
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:24:11 | Осталось: 0:02:53
# Эпизод 269/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 80.04, Кризисов: 56
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:24:16 | Осталось: 0:02:47
# Эпизод 270/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 84.34, Кризисов: 52
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:24:21 | Осталось: 0:02:42
#   Промежуточные результаты сохранены на эпохе 270
# Эпизод 271/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 77.31, Кризисов: 59
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:24:27 | Осталось: 0:02:37
# Эпизод 272/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 73.46, Кризисов: 63
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:24:32 | Осталось: 0:02:31
# Эпизод 273/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 76.07, Кризисов: 60
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:24:37 | Осталось: 0:02:26
# Эпизод 274/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 84.17, Кризисов: 52
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:24:43 | Осталось: 0:02:20
# Эпизод 275/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.08, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:24:48 | Осталось: 0:02:15
# Эпизод 276/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 73.22, Кризисов: 63
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:24:54 | Осталось: 0:02:09
# Эпизод 277/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.12, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:24:59 | Осталось: 0:02:04
# Эпизод 278/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 74.34, Кризисов: 62
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:25:04 | Осталось: 0:01:59
# Эпизод 279/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 86.23, Кризисов: 50
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:25:09 | Осталось: 0:01:53
# Эпизод 280/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 82.40, Кризисов: 54
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:25:15 | Осталось: 0:01:48
# Эпизод 281/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:02 | Осталось: 0:00:01
#   Средняя награда: 75.76, Кризисов: 61
#   Время эпизода: 0:00:04
#   Прошло эксперимента: 0:25:20 | Осталось: 0:01:42
# Эпизод 282/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 82.29, Кризисов: 54
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:25:25 | Осталось: 0:01:37
# Эпизод 283/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 87.07, Кризисов: 49
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:25:31 | Осталось: 0:01:31
# Эпизод 284/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:04 | Осталось: 0:00:02
#   Средняя награда: 66.81, Кризисов: 70
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:25:36 | Осталось: 0:01:26
# Эпизод 285/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.37, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:25:42 | Осталось: 0:01:21
# Эпизод 286/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 71.14, Кризисов: 65
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:25:47 | Осталось: 0:01:15
# Эпизод 287/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 71.21, Кризисов: 65
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:25:53 | Осталось: 0:01:10
# Эпизод 288/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 86.02, Кризисов: 50
#   Время эпизода: 0:00:06
#   Прошло эксперимента: 0:25:59 | Осталось: 0:01:04
# Эпизод 289/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 82.36, Кризисов: 54
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:26:04 | Осталось: 0:00:59
# Эпизод 290/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 79.11, Кризисов: 57
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:26:10 | Осталось: 0:00:54
# Эпизод 291/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 76.29, Кризисов: 60
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:26:15 | Осталось: 0:00:48
# Эпизод 292/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 76.34, Кризисов: 60
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:26:21 | Осталось: 0:00:43
# Эпизод 293/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 75.34, Кризисов: 61
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:26:26 | Осталось: 0:00:37
# Эпизод 294/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 74.64, Кризисов: 62
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:26:32 | Осталось: 0:00:32
# Эпизод 295/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 83.15, Кризисов: 53
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:26:37 | Осталось: 0:00:27
# Эпизод 296/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 88.72, Кризисов: 47
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:26:43 | Осталось: 0:00:21
# Эпизод 297/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 73.35, Кризисов: 63
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:26:48 | Осталось: 0:00:16
# Эпизод 298/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 76.62, Кризисов: 60
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:26:53 | Осталось: 0:00:10
# Эпизод 299/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:02 | Осталось: 0:00:04
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 78.37, Кризисов: 58
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:26:59 | Осталось: 0:00:05
# Эпизод 300/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:01 | Осталось: 0:00:03
#   Шаг 34/51 (66.7%) | Прошло: 0:00:03 | Осталось: 0:00:01
#   Средняя награда: 69.51, Кризисов: 67
#   Время эпизода: 0:00:05
#   Прошло эксперимента: 0:27:04 | Осталось: 0:00:00
#   Промежуточные результаты сохранены на эпохе 300
# Эксперимент с MADDPG завершен.
# Общее время эксперимента: 0:27:04
# === ИТОГОВАЯ СВОДКА ДЛЯ MADDPG ===
# Средняя награда по всем эпизодам: 80.64 ± 7.12
# Общее количество кризисов: 16833
# Общее количество переходов между стадиями: 6935
#
# Топ-5 типов кризисов по частоте:
#   Социальные волнения: 2170 раз
#   Пандемия: 2161 раз
#   Политический переворот: 2144 раз
#   Экономический кризис: 2098 раз
#   Экологическая катастрофа: 2079 раз
#
# Распределение кризисов по странам:
#   Russia: 2099 кризисов
#   Brazil: 810 кризисов
#   Saudi Arabia: 810 кризисов
#   Turkey: 808 кризисов
#   Spain: 804 кризисов
#   United Kingdom: 796 кризисов
#   India: 789 кризисов
#   Mexico: 785 кризисов
#   South Korea: 780 кризисов
#   France: 777 кризисов
#   Netherlands: 773 кризисов
#   United States: 767 кризисов
#   Canada: 766 кризисов
#   Switzerland: 765 кризисов
#   Italy: 763 кризисов
#   China: 762 кризисов
#   Indonesia: 757 кризисов
#   Germany: 756 кризисов
#   Japan: 745 кризисов
#   Australia: 721 кризисов

# %%
# =============================================================================
# БЛОК 2: УЛУЧШЕННЫЙ ЭКСПЕРИМЕНТ С MAPPO (300 ЭПОХ, ГОДОВОЙ ШАГ)
# =============================================================================

import time
import random
import numpy as np
import pandas as pd
from collections import deque, namedtuple
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pickle
import warnings
import json
import requests
from datetime import datetime, timedelta
warnings.filterwarnings("ignore")

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical
import torch.multiprocessing as mp
from torch.utils.tensorboard import SummaryWriter

# Увеличено количество эпох до 300
CONFIG = {
    'start_year': 2017,
    'train_end_year': 2024,
    'sim_start_year': 2025,
    'sim_end_year': 2075,
    'steps_per_year': 1,  # Годовой шаг
    'num_episodes': 300,  # Увеличено до 300
    'top_countries': 20,
    'observation_total_size': 12,
    'observation_in_size': 12,
    'action_size': 45,
    'hidden_dim': 128,
    'lr_actor': 3e-4,
    'lr_critic': 3e-4,
    'gamma': 0.95,
    'tau': 0.02,
    'buffer_size': int(1e5),
    'batch_size': 128,
    'update_every': 5,
    'epsilon_start': 1.0,
    'epsilon_end': 0.01,
    'epsilon_decay': 0.995, # Слегка уменьшено
    'clip_epsilon': 0.2,
    'gae_lambda': 0.95,
    'ppo_epochs': 3,
    'entropy_coef': 0.02,
    'max_grad_norm': 0.5,
    'device': torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    'save_dir': 'experiment_results_mappo_improved_300ep',
    'data_dir': 'data'
}

os.makedirs(CONFIG['save_dir'], exist_ok=True)
os.makedirs(CONFIG['data_dir'], exist_ok=True)

def fetch_world_bank_data(indicator, country_code, start_year, end_year):
    base_url = "http://api.worldbank.org/v2/country"
    url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json&per_page=100"

    try:
        response = requests.get(url, timeout=10)
        data = response.json()
        if len(data) > 1:
            return {item['date']: item['value'] for item in data[1] if item['value'] is not None}
        else:
            return {}
    except Exception as e:
        print(f"Ошибка при загрузке данных для {country_code}, {indicator}: {e}")
        return {}

def load_real_historical_data():
    print("Загрузка реальных исторических данных...")

    countries = {
        "United States": "US", "China": "CN", "Japan": "JP", "Germany": "DE", "India": "IN",
        "United Kingdom": "GB", "France": "FR", "Italy": "IT", "Brazil": "BR", "Canada": "CA",
        "South Korea": "KR", "Russia": "RU", "Australia": "AU", "Spain": "ES", "Mexico": "MX",
        "Indonesia": "ID", "Netherlands": "NL", "Saudi Arabia": "SA", "Turkey": "TR", "Switzerland": "CH"
    }

    indicators = {
        'gdp_growth': 'NY.GDP.MKTP.KD.ZG', 'unemployment': 'SL.UEM.TOTL.ZS', 'inflation': 'FP.CPI.TOTL.ZG',
        'aging_index': 'SP.POP.65UP.TO.ZS', 'migration_net': 'SM.POP.NETM', 'gini_coefficient': 'SI.POV.GINI',
        'corruption_index': 'CC.EST', 'political_stability': 'PV.EST', 'innovation_index': 'GB.XPD.RSDV.GD.ZS',
        'environmental_footprint': 'EN.ATM.CO2E.PC', 'education_index': 'SE.TER.ENRR', 'press_freedom': 'EN.PUB.FREX'
    }

    data = {}

    for country_name, country_code in countries.items():
        print(f"Загрузка данных для {country_name}...")
        country_data = {}

        for indicator_name, indicator_code in indicators.items():
            indicator_data = fetch_world_bank_data(indicator_code, country_code, CONFIG['start_year'], CONFIG['train_end_year'])
            country_data[indicator_name] = indicator_data

        years = list(range(CONFIG['start_year'], CONFIG['train_end_year'] + 1))
        country_array = []

        for year in years:
            year_str = str(year)
            row = []
            for indicator_name in indicators.keys():
                value = country_data[indicator_name].get(year_str, np.nan)
                row.append(value if value is not None else np.nan)
            country_array.append(row)

        country_array = np.array(country_array)
        if len(country_array) > 0:
            df = pd.DataFrame(country_array, columns=list(indicators.keys()))
            df = df.fillna(method='ffill').fillna(method='bfill').fillna(0)
            data[country_name] = df.values
        else:
            data[country_name] = np.zeros((CONFIG['train_end_year'] - CONFIG['start_year'] + 1, len(indicators)))

    print("Реальные данные успешно загружены.")
    return data, list(countries.keys())

def generate_synthetic_data(historical_data, countries):
    print("Генерация синтетических данных...")
    synthetic_data = {}

    for country in countries:
        if country in historical_data and len(historical_data[country]) > 0:
            last_data = historical_data[country][-1]
        else:
            last_data = np.random.randn(CONFIG['observation_total_size']) * 0.1

        sim_years = CONFIG['sim_end_year'] - CONFIG['sim_start_year'] + 1
        country_data = []

        for _ in range(sim_years):
            noise = np.random.randn(len(last_data)) * 0.02  # Увеличен шум для разнообразия
            new_data = last_data + noise
            country_data.append(new_data)
            last_data = new_data

        synthetic_data[country] = np.array(country_data)

    print("Синтетические данные сгенерированы.")
    return synthetic_data

def load_historical_data():
    try:
        real_data, countries = load_real_historical_data()
    except Exception as e:
        print(f"Не удалось загрузить реальные данные: {e}")
        print("Использование синтетических данных...")
        countries = [
            "United States", "China", "Japan", "Germany", "India", "United Kingdom",
            "France", "Italy", "Brazil", "Canada", "South Korea", "Russia", "Australia",
            "Spain", "Mexico", "Indonesia", "Netherlands", "Saudi Arabia", "Turkey", "Switzerland"
        ]

        np.random.seed(42)
        real_data = {}

        for country in countries:
            years = CONFIG['train_end_year'] - CONFIG['start_year'] + 1
            country_data = np.random.randn(years, CONFIG['observation_total_size']) * 0.1
            real_data[country] = country_data

    synthetic_data = generate_synthetic_data(real_data, countries)
    return real_data, synthetic_data, countries

class CountrySystem:
    def __init__(self, name, initial_state):
        self.name = name
        self.state = initial_state.copy()
        self.internal_state = self._initialize_internal_state()
        self.stage = "I. Конструктивная адаптация"
        self.history = []
        self.crisis_history = []
        self.stage_transitions = []
        self.step_count = 0
        self.year = CONFIG['sim_start_year']

    def _initialize_internal_state(self):
        return np.array([
            0.8, 1.0, 0.7, 0.75, 0.6, 0.5, 0.2, 0.8, 0.3, 0.5, 0.7, 0.6
        ])

    def get_observation_total(self):
        return self.state

    def get_observation_in(self):
        return self.internal_state

    def apply_action(self, action):
        reward = 0
        crisis_event = None

        self._update_internal_state(action)
        self._update_external_state(action)

        crisis_event = self._check_for_crisis()
        if crisis_event:
            self.crisis_history.append({
                'step': self.step_count, 'year': self.year, 'crisis': crisis_event
            })
            reward -= 50  # Уменьшен штраф за кризис

        new_stage = self._check_stage_transition()
        if new_stage != self.stage:
            self.stage_transitions.append({
                'step': self.step_count, 'year': self.year,
                'from_stage': self.stage, 'to_stage': new_stage
            })
            self.stage = new_stage
            reward += self._get_stage_reward(new_stage)

        reward += self._calculate_stability_reward()

        self.step_count += 1
        self.year += 1

        self.history.append({
            'step': self.step_count, 'state': self.state.copy(), 'internal_state': self.internal_state.copy(),
            'stage': self.stage, 'year': self.year
        })

        return reward, crisis_event is not None

    def _update_internal_state(self, action):
        action_effects = np.zeros_like(self.internal_state)

        if action == 0:  # Повышение налогов
            action_effects[0] -= 0.02; action_effects[2] -= 0.01; action_effects[9] -= 0.01
        elif action == 1:  # Снижение налогов
            action_effects[0] += 0.01; action_effects[2] += 0.01; action_effects[9] += 0.02
        elif action == 2:  # Увеличение социальных расходов
            action_effects[4] += 0.03; action_effects[10] += 0.02; action_effects[9] += 0.01
        elif action == 3:  # Сокращение социальных расходов
            action_effects[4] -= 0.02; action_effects[10] -= 0.01; action_effects[9] -= 0.01
        elif action == 4:  # Реформа пенсионной системы
            action_effects[4] += 0.02; action_effects[1] += 0.02
        elif action == 5:  # Реформа здравоохранения
            action_effects[0] += 0.01; action_effects[10] += 0.01
        elif action == 6:  # Инвестиции в образование и науку
            action_effects[5] += 0.03; action_effects[7] += 0.02
        elif action == 7:  # Поддержка инноваций и стартапов
            action_effects[5] += 0.04; action_effects[11] += 0.03
        elif action == 8:  # Ужесточение миграционной политики
            action_effects[4] -= 0.01; action_effects[10] -= 0.01
        elif action == 9:  # Либерализация миграционной политики
            action_effects[4] += 0.02; action_effects[10] += 0.01
        elif action == 10: # Проведение амнистии для мигрантов
            action_effects[4] += 0.01; action_effects[10] += 0.02
        elif action == 11: # Усиление полицейского контроля
            action_effects[0] -= 0.01; action_effects[9] -= 0.02
        elif action == 12: # Снижение репрессий, декриминализация
            action_effects[0] += 0.02; action_effects[9] += 0.01
        elif action == 13: # Проведение выборов (честных, свободных)
            action_effects[0] += 0.03; action_effects[7] += 0.03
        elif action == 14: # Фальсификация выборов
            action_effects[0] -= 0.03; action_effects[7] -= 0.02
        elif action == 15: # Роспуск парламента
            action_effects[0] -= 0.02; action_effects[8] += 0.03
        elif action == 16: # Распуск оппозиционных партий
            action_effects[0] -= 0.03; action_effects[7] -= 0.02
        elif action == 17: # Преследование оппозиционеров
            action_effects[0] -= 0.02; action_effects[8] += 0.02
        elif action == 18: # Амнистия политзаключенных
            action_effects[0] += 0.01; action_effects[10] += 0.01
        elif action == 19: # Реформа судебной системы
            action_effects[0] += 0.02; action_effects[11] += 0.01
        elif action == 20: # Укрепление независимости судов
            action_effects[0] += 0.03; action_effects[7] += 0.02
        elif action == 21: # Подавление свободы слова
            action_effects[0] -= 0.03; action_effects[7] -= 0.02
        elif action == 22: # Поддержка свободы слова
            action_effects[0] += 0.03; action_effects[7] += 0.02
        elif action == 23: # Введение цензуры
            action_effects[0] -= 0.02; action_effects[8] += 0.02
        elif action == 24: # Поддержка СМИ
            action_effects[0] += 0.02; action_effects[7] += 0.01
        elif action == 25: # Проведение референдума
            action_effects[0] += 0.01; action_effects[7] += 0.01
        elif action == 26: # Реформа конституции
            action_effects[11] += 0.03; action_effects[5] -= 0.01
        elif action == 27: # Увеличение числа чиновников
            action_effects[1] -= 0.01; action_effects[8] += 0.01
        elif action == 28: # Сокращение бюрократии
            action_effects[1] += 0.02; action_effects[11] += 0.01
        elif action == 29: # Борьба с коррупцией (эффективная)
            action_effects[0] += 0.03; action_effects[10] += 0.02
        elif action == 30: # Имитация борьбы с коррупцией
            action_effects[0] -= 0.01; action_effects[10] -= 0.01
        elif action == 31: # Заключение торгового соглашения
            action_effects[3] += 0.01; action_effects[11] += 0.01
        elif action == 32: # Введение торговых пошлин/санкций
            action_effects[3] -= 0.01; action_effects[9] -= 0.01
        elif action == 33: # Поддержка экспорта
            action_effects[3] += 0.02; action_effects[11] += 0.01
        elif action == 34: # Поддержка импорта
            action_effects[3] += 0.01; action_effects[5] -= 0.01
        elif action == 35: # Заключение военного альянса
            action_effects[9] -= 0.02; action_effects[8] += 0.01
        elif action == 36: # Выход из военного альянса
            action_effects[9] += 0.01; action_effects[11] += 0.01
        elif action == 37: # Начало переговоров
            action_effects[0] += 0.01; action_effects[3] += 0.01
        elif action == 38: # Прекращение переговоров
            action_effects[0] -= 0.01; action_effects[3] -= 0.01
        elif action == 39: # Ведение войны (наступательной)
            action_effects[9] -= 0.03; action_effects[8] += 0.03
        elif action == 40: # Ведение войны (оборонительной)
            action_effects[9] -= 0.02; action_effects[10] -= 0.01
        elif action == 41: # Отправка миротворцев
            action_effects[0] += 0.01; action_effects[3] += 0.01
        elif action == 42: # Принятие беженцев
            action_effects[4] += 0.02; action_effects[10] += 0.01
        elif action == 43: # Отказ от беженцев
            action_effects[4] -= 0.01; action_effects[10] -= 0.01
        elif action == 44: # Мирная экспансия
            action_effects[5] += 0.02; action_effects[11] += 0.02

        self.internal_state = np.clip(self.internal_state + action_effects, 0.0, 1.0)

    def _update_external_state(self, action):
        noise = np.random.normal(0, 0.02, len(self.state))  # Увеличен шум
        self.state = self.state + noise

        if action == 0:
            self.state[0] -= 0.05; self.state[1] += 0.1
        elif action == 2:
            self.state[4] += 0.05; self.state[6] -= 0.03
        elif action == 6:
            self.state[8] += 0.02
        elif action == 7:
            self.state[8] += 0.03
        elif action == 39:
            self.state[0] -= 0.2; self.state[1] += 0.3; self.state[2] += 0.2

    def _check_for_crisis(self):
        crisis_probability = 0.0

        # Базовая вероятность кризиса
        crisis_probability += 0.05

        # Кризисы первого бугра (перепроизводство элиты)
        if self.internal_state[4] < 0.4 and self.state[5] > 0.6:
            crisis_probability += 0.15

        # Кризисы второго бугра (молодые мигранты)
        if self.state[4] > 0.8 and self.internal_state[10] < 0.5:
            crisis_probability += 0.12

        # Общая нестабильность
        if self.internal_state[0] < 0.4 and self.internal_state[2] < 0.5:
            crisis_probability += 0.18

        # Экономический кризис
        if self.state[0] < -1.0 or self.state[1] > 12.0:
            crisis_probability += 0.25

        if np.random.random() < crisis_probability:
            crises = ["Политический переворот", "Экономический кризис", "Социальные волнения",
                     "Военный конфликт", "Экологическая катастрофа", "Финансовый крах",
                     "Пандемия", "Технологическая катастрофа"]
            return np.random.choice(crises)

        return None

    def _check_stage_transition(self):
        if (self.internal_state[0] > 0.75 and self.internal_state[2] > 0.75 and
            self.internal_state[10] > 0.75 and self.internal_state[4] > 0.65):
            return "Точка Превосходства"

        elif (self.internal_state[5] > 0.65 and self.internal_state[7] < 0.35 and
              self.internal_state[1] < 0.45):
            return "Точка Плато (Застой)"

        elif (self.internal_state[6] > 0.75 and self.internal_state[9] < 0.25 and
              self.internal_state[8] > 0.65):
            return "Точка Перенапряжения"

        elif (self.internal_state[10] < 0.25 and self.internal_state[0] < 0.25 and
              self.internal_state[7] < 0.15):
            return "Точка Гибели/Перезапуска"

        if self.internal_state[5] > 0.55 and self.internal_state[7] < 0.45:
            return "III. Деструктивная экспансия"
        elif self.internal_state[5] < 0.45 and self.internal_state[7] > 0.55:
            return "I. Конструктивная адаптация"
        elif self.internal_state[5] > 0.45 and self.internal_state[7] > 0.45:
            return "II. Конструктивная экспансия"
        else:
            return "IV. Деструктивная адаптация (кризис)"

    def _get_stage_reward(self, stage):
        rewards = {
            "Точка Превосходства": 80,      # Уменьшена награда
            "I. Конструктивная адаптация": 40,
            "II. Конструктивная экспансия": 40,
            "Точка Плато (Застой)": -5,
            "III. Деструктивная экспансия": -30,
            "Точка Перенапряжения": -60,
            "IV. Деструктивная адаптация (кризис)": -120,
            "Точка Гибели/Перезапуска": -800  # Уменьшен штраф
        }
        return rewards.get(stage, 0)

    def _calculate_stability_reward(self):
        stability_reward = 0
        balance = abs(self.internal_state[5] - 0.5)
        stability_reward += (1 - balance) * 5  # Уменьшена награда
        stability_reward += self.internal_state[0] * 3
        stability_reward -= self.internal_state[6] * 5
        stability_reward += self.internal_state[4] * 2
        stability_reward -= self.internal_state[8] * 3
        return stability_reward

class MAPPOActor(nn.Module):
    def __init__(self, obs_dim, action_dim, hidden_dim=CONFIG['hidden_dim']):
        super(MAPPOActor, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_dim, hidden_dim), nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim), nn.ReLU(),
            nn.Linear(hidden_dim, action_dim), nn.Softmax(dim=-1)
        )

    def forward(self, obs):
        return self.net(obs)

class MAPPOCritic(nn.Module):
    def __init__(self, obs_dim, num_agents, hidden_dim=CONFIG['hidden_dim']):
        super(MAPPOCritic, self).__init__()
        self.num_agents = num_agents
        total_obs_dim = obs_dim * num_agents

        self.net = nn.Sequential(
            nn.Linear(total_obs_dim, hidden_dim), nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim), nn.ReLU(),
            nn.Linear(hidden_dim, 1)
        )

    def forward(self, obs):
        if isinstance(obs, list):
            obs_flat = torch.cat(obs, dim=-1)
        elif isinstance(obs, torch.Tensor):
            obs_flat = obs
        else:
            obs_flat = torch.FloatTensor(obs).to(CONFIG['device'])
            if len(obs_flat.shape) == 1:
                obs_flat = obs_flat.unsqueeze(0)

        return self.net(obs_flat)

class MAPPOAgent:
    def __init__(self, obs_total_dim, obs_in_dim, action_dim, agent_id, num_agents):
        self.agent_id = agent_id
        self.action_dim = action_dim
        self.obs_dim = obs_total_dim + obs_in_dim
        self.num_agents = num_agents

        self.actor = MAPPOActor(self.obs_dim, action_dim).to(CONFIG['device'])
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=CONFIG['lr_actor'])

        self.critic = MAPPOCritic(self.obs_dim, num_agents).to(CONFIG['device'])
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=CONFIG['lr_critic'])

        self.trajectories = []

    def act(self, obs_total, obs_in):
        obs = torch.FloatTensor(np.concatenate([obs_total, obs_in])).unsqueeze(0).to(CONFIG['device'])
        action_probs = self.actor(obs)
        dist = Categorical(action_probs)
        action = dist.sample()

        log_prob = dist.log_prob(action)
        value = 0.0  # Заглушка, будет вычислено позже

        return action.item(), log_prob.item(), value, action_probs.detach().cpu().numpy()

    def store_trajectory(self, transition):
        self.trajectories.append(transition)

    def compute_returns_and_advantages(self, rewards, values, dones):
        returns = []
        gae = 0
        values = list(values) + [0]

        for i in reversed(range(len(rewards))):
            if dones[i]:
                delta = rewards[i] - values[i]
                gae = delta
            else:
                delta = rewards[i] + CONFIG['gamma'] * values[i+1] - values[i]
                gae = delta + CONFIG['gamma'] * CONFIG['gae_lambda'] * gae

            returns.insert(0, gae + values[i])

        advantages = [returns[i] - values[i] for i in range(len(returns))]
        return returns, advantages

    def update(self, agents, all_observations_total_list, all_observations_in_list):
        if len(self.trajectories) == 0:
            return

        # Извлечение данных из траекторий
        states, actions, log_probs_old, values_old, rewards, dones = zip(*self.trajectories)

        # Преобразование в тензоры
        states_tensor = torch.FloatTensor(np.array(states)).to(CONFIG['device'])
        actions_tensor = torch.LongTensor(actions).to(CONFIG['device'])
        log_probs_old_tensor = torch.FloatTensor(log_probs_old).to(CONFIG['device'])
        values_old_tensor = torch.FloatTensor(values_old).to(CONFIG['device'])
        rewards_tensor = torch.FloatTensor(rewards).to(CONFIG['device'])
        dones_tensor = torch.BoolTensor(dones).to(CONFIG['device'])

        # Вычисление возвращений и преимуществ
        returns, advantages = self.compute_returns_and_advantages(
            rewards_tensor.cpu().numpy(),
            values_old_tensor.cpu().numpy(),
            dones_tensor.cpu().numpy()
        )
        returns_tensor = torch.FloatTensor(returns).to(CONFIG['device'])
        advantages_tensor = torch.FloatTensor(advantages).to(CONFIG['device'])

        # Нормализация преимуществ
        advantages_tensor = (advantages_tensor - advantages_tensor.mean()) / (advantages_tensor.std() + 1e-8)

        # Обновление несколько раз (PPO epochs)
        for _ in range(CONFIG['ppo_epochs']):
            # Обновление критика
            # Формируем тензор всех наблюдений для критика
            all_obs_list = []
            for i in range(len(all_observations_total_list)):
                obs_total = all_observations_total_list[i]
                obs_in = all_observations_in_list[i]
                obs_combined = np.concatenate([obs_total, obs_in])
                all_obs_list.append(torch.FloatTensor(obs_combined).unsqueeze(0).to(CONFIG['device']))

            values = self.critic(all_obs_list).squeeze(-1)
            # Обрезаем, если размеры не совпадают
            min_len = min(len(values), len(returns_tensor))
            critic_loss = F.mse_loss(values[:min_len], returns_tensor[:min_len])

            self.critic_optimizer.zero_grad()
            critic_loss.backward()
            torch.nn.utils.clip_grad_norm_(self.critic.parameters(), CONFIG['max_grad_norm'])
            self.critic_optimizer.step()

            # Обновление актера
            # Обрезаем, если размеры не совпадают
            min_len = min(len(actions_tensor), len(log_probs_old_tensor), len(advantages_tensor))
            action_probs = self.actor(states_tensor[:min_len])
            dist = Categorical(action_probs)
            log_probs_new = dist.log_prob(actions_tensor[:min_len])

            ratio = torch.exp(log_probs_new - log_probs_old_tensor[:min_len])
            surr1 = ratio * advantages_tensor[:min_len]
            surr2 = torch.clamp(ratio, 1 - CONFIG['clip_epsilon'], 1 + CONFIG['clip_epsilon']) * advantages_tensor[:min_len]
            actor_loss = -torch.min(surr1, surr2).mean()

            # Добавление регуляризации энтропии
            entropy = dist.entropy().mean()
            actor_loss -= CONFIG['entropy_coef'] * entropy

            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            torch.nn.utils.clip_grad_norm_(self.actor.parameters(), CONFIG['max_grad_norm'])
            self.actor_optimizer.step()

        # Очистка траекторий
        self.trajectories = []

def run_mappo_experiment():
    print("Запуск улучшенного эксперимента с MAPPO агентами (300 эпох)...")

    real_data, synthetic_data, countries = load_historical_data()

    country_systems = {}
    for country in countries:
        if country in real_data and len(real_data[country]) > 0:
            initial_state = real_data[country][-1]
        else:
            initial_state = synthetic_data[country][0] if len(synthetic_data[country]) > 0 else np.zeros(CONFIG['observation_total_size'])
        country_systems[country] = CountrySystem(country, initial_state)

    agents = {}
    obs_total_dim = CONFIG['observation_total_size']
    obs_in_dim = CONFIG['observation_in_size']
    action_dim = CONFIG['action_size']
    num_agents = len(countries)

    for i, country in enumerate(countries):
        agents[country] = MAPPOAgent(obs_total_dim, obs_in_dim, action_dim, i, num_agents)

    all_rewards = []
    all_crisis_histories = {country: [] for country in countries}
    all_stage_transitions = {country: [] for country in countries}
    final_states = {}

    timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
    writer = SummaryWriter(f'runs/MAPPO_experiment_improved_300ep_{timestamp}')

    experiment_start_time = time.time()

    # Для более удобного мониторинга при 300 эпохах
    progress_interval = 30

    for episode in range(CONFIG['num_episodes']):
        episode_start_time = time.time()
        print(f"Эпизод {episode + 1}/{CONFIG['num_episodes']}")

        for country in countries:
            if country in real_data and len(real_data[country]) > 0:
                initial_state = real_data[country][-1]
            else:
                initial_state = synthetic_data[country][0] if len(synthetic_data[country]) > 0 else np.zeros(CONFIG['observation_total_size'])
            country_systems[country] = CountrySystem(country, initial_state)

        for agent in agents.values():
            agent.trajectories = []

        episode_rewards = []
        episode_crisis_count = 0

        total_steps = CONFIG['sim_end_year'] - CONFIG['sim_start_year'] + 1
        episode_step_start_time = time.time()

        for step in range(total_steps):
            observations_total = []
            observations_in = []
            actions = []

            for country in countries:
                obs_total = country_systems[country].get_observation_total()
                obs_in = country_systems[country].get_observation_in()
                observations_total.append(obs_total)
                observations_in.append(obs_in)

            for country in countries:
                action, log_prob, value, action_probs = agents[country].act(
                    observations_total[countries.index(country)],
                    observations_in[countries.index(country)]
                )
                actions.append(action)

            rewards = []
            for i, country in enumerate(countries):
                reward, crisis_occurred = country_systems[country].apply_action(actions[i])
                rewards.append(reward)
                if crisis_occurred:
                    episode_crisis_count += 1

            episode_rewards.append(sum(rewards))

            for i, country in enumerate(countries):
                transition = (
                    np.concatenate([observations_total[i], observations_in[i]]),
                    actions[i],
                    0,
                    0,
                    rewards[i],
                    step == total_steps - 1
                )
                agents[country].store_trajectory(transition)

            # Обновлено: вывод прогресса реже при 300 эпохах
            if step > 0 and step % max(1, total_steps // 3) == 0: # Примерно 3 точки отчета за эпоху
                elapsed_step_time = time.time() - episode_step_start_time
                steps_remaining = total_steps - step
                estimated_time_remaining = (elapsed_step_time / step) * steps_remaining if step > 0 else 0
                print(f"  Шаг {step}/{total_steps} ({step/total_steps*100:.1f}%) | "
                      f"Прошло: {timedelta(seconds=int(elapsed_step_time))} | "
                      f"Осталось: {timedelta(seconds=int(estimated_time_remaining))}")

        # Собираем все наблюдения для обновления
        all_observations_total_list = []
        all_observations_in_list = []
        for country in countries:
            obs_total = country_systems[country].get_observation_total()
            obs_in = country_systems[country].get_observation_in()
            all_observations_total_list.append(obs_total)
            all_observations_in_list.append(obs_in)

        for country in countries:
            agents[country].update(list(agents.values()), all_observations_total_list, all_observations_in_list)

        avg_reward = np.mean(episode_rewards)
        all_rewards.append(avg_reward)

        for country in countries:
            all_crisis_histories[country].extend(country_systems[country].crisis_history)
            all_stage_transitions[country].extend(country_systems[country].stage_transitions)

        writer.add_scalar('Average Reward', avg_reward, episode)
        writer.add_scalar('Crisis Count', episode_crisis_count, episode)

        episode_elapsed_time = time.time() - episode_start_time
        episodes_remaining = CONFIG['num_episodes'] - episode - 1
        experiment_elapsed_time = time.time() - experiment_start_time
        estimated_total_experiment_time = (experiment_elapsed_time / (episode + 1)) * CONFIG['num_episodes']
        estimated_experiment_remaining = estimated_total_experiment_time - experiment_elapsed_time

        print(f"  Средняя награда: {avg_reward:.2f}, Кризисов: {episode_crisis_count}")
        print(f"  Время эпизода: {timedelta(seconds=int(episode_elapsed_time))}")
        print(f"  Прошло эксперимента: {timedelta(seconds=int(experiment_elapsed_time))} | "
              f"Осталось: {timedelta(seconds=int(estimated_experiment_remaining))}")

        # Добавлено: Промежуточное сохранение каждые progress_interval эпох
        if (episode + 1) % progress_interval == 0:
            intermediate_results = {
                'all_rewards': all_rewards,
                'all_crisis_histories': all_crisis_histories,
                'all_stage_transitions': all_stage_transitions,
                'countries': countries,
                'current_episode': episode + 1
            }
            with open(f"{CONFIG['save_dir']}/MAPPO_intermediate_results_ep_{episode+1}.pkl", 'wb') as f:
                pickle.dump(intermediate_results, f)
            print(f"  Промежуточные результаты сохранены на эпохе {episode+1}")

    for country in countries:
        final_states[country] = country_systems[country].state

    writer.close()

    results = {
        'final_states': final_states,
        'all_rewards': all_rewards,
        'all_crisis_histories': all_crisis_histories,
        'all_stage_transitions': all_stage_transitions,
        'countries': countries
    }

    with open(f"{CONFIG['save_dir']}/MAPPO_results.pkl", 'wb') as f:
        pickle.dump(results, f)

    experiment_total_time = time.time() - experiment_start_time
    print(f"Эксперимент с MAPPO завершен.")
    print(f"Общее время эксперимента: {timedelta(seconds=int(experiment_total_time))}")
    return results

def plot_mappo_results(results):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))

    # График наград по эпизодам
    axes[0, 0].plot(results['all_rewards'], label='MAPPO', alpha=0.7, linewidth=2, color='blue')
    axes[0, 0].set_xlabel('Эпизод')
    axes[0, 0].set_ylabel('Средняя награда')
    axes[0, 0].set_title('Средние награды MAPPO по эпизодам')
    axes[0, 0].legend()
    axes[0, 0].grid(True)

    # Скользящее среднее наград
    window_size = 10
    rewards_smooth = pd.Series(results['all_rewards']).rolling(window=window_size).mean()
    axes[0, 1].plot(rewards_smooth, label='MAPPO (скользящее среднее)', alpha=0.7, linewidth=2, color='green')
    axes[0, 1].set_xlabel('Эпизод')
    axes[0, 1].set_ylabel('Средняя награда')
    axes[0, 1].set_title(f'Скользящее среднее наград (окно={window_size})')
    axes[0, 1].legend()
    axes[0, 1].grid(True)

    # Распределение кризисов по странам
    crisis_counts = [len(results['all_crisis_histories'][country]) for country in results['countries']]
    axes[1, 0].bar(range(len(results['countries'])), crisis_counts, color='red', alpha=0.7)
    axes[1, 0].set_xlabel('Страны')
    axes[1, 0].set_ylabel('Количество кризисов')
    axes[1, 0].set_title('Распределение кризисов по странам')
    axes[1, 0].set_xticks(range(len(results['countries'])))
    axes[1, 0].set_xticklabels(results['countries'], rotation=45, ha='right')
    axes[1, 0].grid(True)

    # Распределение переходов по странам
    transition_counts = [len(results['all_stage_transitions'][country]) for country in results['countries']]
    axes[1, 1].bar(range(len(results['countries'])), transition_counts, color='orange', alpha=0.7)
    axes[1, 1].set_xlabel('Страны')
    axes[1, 1].set_ylabel('Количество переходов')
    axes[1, 1].set_title('Распределение переходов по странам')
    axes[1, 1].set_xticks(range(len(results['countries'])))
    axes[1, 1].set_xticklabels(results['countries'], rotation=45, ha='right')
    axes[1, 1].grid(True)

    plt.tight_layout()
    plt.savefig(f"{CONFIG['save_dir']}/MAPPO_detailed_analysis.png", dpi=300, bbox_inches='tight')
    plt.show()

def print_mappo_summary(results):
    print("\n=== ИТОГОВАЯ СВОДКА ДЛЯ MAPPO ===")

    avg_reward = np.mean(results['all_rewards'])
    std_reward = np.std(results['all_rewards'])
    print(f"Средняя награда по всем эпизодам: {avg_reward:.2f} ± {std_reward:.2f}")

    total_crises = sum(len(crises) for crises in results['all_crisis_histories'].values())
    print(f"Общее количество кризисов: {total_crises}")

    total_transitions = sum(len(transitions) for transitions in results['all_stage_transitions'].values())
    print(f"Общее количество переходов между стадиями: {total_transitions}")

    crisis_types = []
    for crises in results['all_crisis_histories'].values():
        for crisis in crises:
            crisis_types.append(crisis['crisis'])

    if crisis_types:
        from collections import Counter
        crisis_counter = Counter(crisis_types)
        print("\nТоп-5 типов кризисов по частоте:")
        for crisis, count in crisis_counter.most_common(5):
            print(f"  {crisis}: {count} раз")

    print("\nРаспределение кризисов по странам:")
    country_crises = [(country, len(crises)) for country, crises in results['all_crisis_histories'].items()]
    country_crises.sort(key=lambda x: x[1], reverse=True)
    for country, count in country_crises:
        print(f"  {country}: {count} кризисов")

    with open(f"{CONFIG['save_dir']}/MAPPO_detailed_summary.txt", 'w', encoding='utf-8') as f:
        f.write("ИТОГОВАЯ СВОДКА ДЛЯ MAPPO\n")
        f.write("=" * 50 + "\n")
        f.write(f"Средняя награда по всем эпизодам: {avg_reward:.2f} ± {std_reward:.2f}\n")
        f.write(f"Общее количество кризисов: {total_crises}\n")
        f.write(f"Общее количество переходов между стадиями: {total_transitions}\n\n")

        f.write("Топ-5 типов кризисов по частоте:\n")
        if crisis_types:
            crisis_counter = Counter(crisis_types)
            for crisis, count in crisis_counter.most_common(5):
                f.write(f"  {crisis}: {count} раз\n")

        f.write("\nИстория кризисов по странам:\n")
        for country, crises in results['all_crisis_histories'].items():
            if crises:
                f.write(f"\n{country} ({len(crises)} кризисов):\n")
                for crisis in crises:
                    f.write(f"  Год {crisis['year']}: {crisis['crisis']}\n")

        f.write("\n\nИстория переходов между стадиями по странам:\n")
        for country, transitions in results['all_stage_transitions'].items():
            if transitions:
                f.write(f"\n{country} ({len(transitions)} переходов):\n")
                for transition in transitions:
                    f.write(f"  Год {transition['year']}: "
                           f"{transition['from_stage']} -> {transition['to_stage']}\n")

def prevent_runtime_disconnect():
    print("Для предотвращения отключения среды введите '555' и нажмите Enter:")
    while True:
        user_input = input()
        if user_input == "555":
            print("Среда защищена от отключения.")
            break
        else:
            print("Неверный код. Пожалуйста, введите '555':")

if __name__ == "__main__":
    prevent_runtime_disconnect()
    print("\n" + "=" * 50)
    print("ЗАПУСК УЛУЧШЕННОГО MAPPO ЭКСПЕРИМЕНТА (300 ЭПОХ)")
    print("=" * 50)
    mappo_results = run_mappo_experiment()
    plot_mappo_results(mappo_results)
    print_mappo_summary(mappo_results)
# Out:
# Для предотвращения отключения среды введите '555' и нажмите Enter:
# 555
# Среда защищена от отключения.
#
# ==================================================
# ЗАПУСК УЛУЧШЕННОГО MAPPO ЭКСПЕРИМЕНТА (300 ЭПОХ)
# ==================================================
# Запуск улучшенного эксперимента с MAPPO агентами (300 эпох)...
# Загрузка реальных исторических данных...
# Загрузка данных для United States...
# Загрузка данных для China...
# Загрузка данных для Japan...
# Загрузка данных для Germany...
# Загрузка данных для India...
# Загрузка данных для United Kingdom...
# Загрузка данных для France...
# Загрузка данных для Italy...
# Загрузка данных для Brazil...
# Загрузка данных для Canada...
# Загрузка данных для South Korea...
# Загрузка данных для Russia...
# Загрузка данных для Australia...
# Загрузка данных для Spain...
# Загрузка данных для Mexico...
# Загрузка данных для Indonesia...
# Загрузка данных для Netherlands...
# Загрузка данных для Saudi Arabia...
# Загрузка данных для Turkey...
# Загрузка данных для Switzerland...
# Реальные данные успешно загружены.
# Генерация синтетических данных...
# Синтетические данные сгенерированы.
# Эпизод 1/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 69.02, Кризисов: 76
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:00 | Осталось: 0:04:13
# Эпизод 2/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 84.70, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:01 | Осталось: 0:04:27
# Эпизод 3/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.68, Кризисов: 59
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:02 | Осталось: 0:04:24
# Эпизод 4/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 89.60, Кризисов: 55
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:03 | Осталось: 0:04:18
# Эпизод 5/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 80.78, Кризисов: 64
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:04 | Осталось: 0:04:12
# Эпизод 6/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 82.74, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:05 | Осталось: 0:04:09
# Эпизод 7/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.68, Кризисов: 59
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:05 | Осталось: 0:04:05
# Эпизод 8/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 79.80, Кризисов: 65
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:06 | Осталось: 0:04:04
# Эпизод 9/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 78.82, Кризисов: 66
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:07 | Осталось: 0:04:01
# Эпизод 10/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 83.72, Кризисов: 61
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:08 | Осталось: 0:04:05
# Эпизод 11/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 75.88, Кризисов: 69
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:00:09 | Осталось: 0:04:14
# Эпизод 12/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 100.82, Кризисов: 47
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:00:10 | Осталось: 0:04:17
# Эпизод 13/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 84.16, Кризисов: 64
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:11 | Осталось: 0:04:15
# Эпизод 14/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 79.26, Кризисов: 69
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:12 | Осталось: 0:04:12
# Эпизод 15/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.00, Кризисов: 56
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:13 | Осталось: 0:04:11
# Эпизод 16/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 82.20, Кризисов: 66
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:14 | Осталось: 0:04:09
# Эпизод 17/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 90.04, Кризисов: 58
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:14 | Осталось: 0:04:06
# Эпизод 18/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 97.88, Кризисов: 50
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:15 | Осталось: 0:04:04
# Эпизод 19/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 78.28, Кризисов: 70
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:16 | Осталось: 0:04:02
# Эпизод 20/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 89.06, Кризисов: 59
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:17 | Осталось: 0:04:00
# Эпизод 21/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 82.20, Кризисов: 66
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:18 | Осталось: 0:04:00
# Эпизод 22/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 99.84, Кризисов: 48
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:18 | Осталось: 0:03:59
# Эпизод 23/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 84.16, Кризисов: 64
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:19 | Осталось: 0:03:59
# Эпизод 24/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 98.86, Кризисов: 49
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:20 | Осталось: 0:03:59
# Эпизод 25/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 83.18, Кризисов: 65
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:00:22 | Осталось: 0:04:02
# Эпизод 26/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 78.28, Кризисов: 70
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:23 | Осталось: 0:04:02
# Эпизод 27/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:23 | Осталось: 0:04:01
# Эпизод 28/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 87.10, Кризисов: 61
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:24 | Осталось: 0:03:59
# Эпизод 29/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:25 | Осталось: 0:03:57
# Эпизод 30/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.14, Кризисов: 63
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:26 | Осталось: 0:03:56
#   Промежуточные результаты сохранены на эпохе 30
# Эпизод 31/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 75.33, Кризисов: 73
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:27 | Осталось: 0:03:54
# Эпизод 32/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 81.22, Кризисов: 67
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:27 | Осталось: 0:03:53
# Эпизод 33/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 77.29, Кризисов: 71
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:28 | Осталось: 0:03:52
# Эпизод 34/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 81.22, Кризисов: 67
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:29 | Осталось: 0:03:52
# Эпизод 35/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 86.12, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:30 | Осталось: 0:03:51
# Эпизод 36/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 97.88, Кризисов: 50
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:31 | Осталось: 0:03:49
# Эпизод 37/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:32 | Осталось: 0:03:48
# Эпизод 38/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 73.37, Кризисов: 75
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:00:33 | Осталось: 0:03:49
# Эпизод 39/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 95.92, Кризисов: 52
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:00:34 | Осталось: 0:03:50
# Эпизод 40/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 80.24, Кризисов: 68
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:35 | Осталось: 0:03:48
# Эпизод 41/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 84.16, Кризисов: 64
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:35 | Осталось: 0:03:47
# Эпизод 42/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 84.16, Кризисов: 64
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:36 | Осталось: 0:03:45
# Эпизод 43/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 77.29, Кризисов: 71
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:37 | Осталось: 0:03:44
# Эпизод 44/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.14, Кризисов: 63
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:38 | Осталось: 0:03:43
# Эпизод 45/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.00, Кризисов: 56
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:39 | Осталось: 0:03:42
# Эпизод 46/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 89.06, Кризисов: 59
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:40 | Осталось: 0:03:41
# Эпизод 47/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 99.84, Кризисов: 48
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:41 | Осталось: 0:03:40
# Эпизод 48/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.98, Кризисов: 55
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:41 | Осталось: 0:03:39
# Эпизод 49/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.14, Кризисов: 63
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:42 | Осталось: 0:03:38
# Эпизод 50/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 86.12, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:43 | Осталось: 0:03:36
# Эпизод 51/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 95.92, Кризисов: 52
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:44 | Осталось: 0:03:35
# Эпизод 52/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 77.29, Кризисов: 71
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:45 | Осталось: 0:03:35
# Эпизод 53/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.00, Кризисов: 56
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:00:46 | Осталось: 0:03:35
# Эпизод 54/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.98, Кризисов: 55
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:47 | Осталось: 0:03:34
# Эпизод 55/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 93.96, Кризисов: 54
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:47 | Осталось: 0:03:33
# Эпизод 56/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:48 | Осталось: 0:03:32
# Эпизод 57/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 81.22, Кризисов: 67
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:49 | Осталось: 0:03:31
# Эпизод 58/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 78.28, Кризисов: 70
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:50 | Осталось: 0:03:30
# Эпизод 59/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 89.06, Кризисов: 59
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:51 | Осталось: 0:03:29
# Эпизод 60/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 91.02, Кризисов: 57
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:52 | Осталось: 0:03:28
#   Промежуточные результаты сохранены на эпохе 60
# Эпизод 61/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 86.12, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:52 | Осталось: 0:03:27
# Эпизод 62/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 87.10, Кризисов: 61
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:53 | Осталось: 0:03:26
# Эпизод 63/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.00, Кризисов: 56
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:54 | Осталось: 0:03:26
# Эпизод 64/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 87.10, Кризисов: 61
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:55 | Осталось: 0:03:24
# Эпизод 65/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 83.18, Кризисов: 65
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:56 | Осталось: 0:03:24
# Эпизод 66/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.98, Кризисов: 55
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:00:57 | Осталось: 0:03:24
# Эпизод 67/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 81.22, Кризисов: 67
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:58 | Осталось: 0:03:23
# Эпизод 68/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.98, Кризисов: 55
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:59 | Осталось: 0:03:21
# Эпизод 69/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 91.02, Кризисов: 57
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:00:59 | Осталось: 0:03:20
# Эпизод 70/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 94.94, Кризисов: 53
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:00 | Осталось: 0:03:20
# Эпизод 71/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 68.47, Кризисов: 80
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:01 | Осталось: 0:03:19
# Эпизод 72/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 81.22, Кризисов: 67
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:02 | Осталось: 0:03:18
# Эпизод 73/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 80.24, Кризисов: 68
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:03 | Осталось: 0:03:17
# Эпизод 74/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:04 | Осталось: 0:03:16
# Эпизод 75/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 81.22, Кризисов: 67
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:05 | Осталось: 0:03:15
# Эпизод 76/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 84.16, Кризисов: 64
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:05 | Осталось: 0:03:14
# Эпизод 77/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.14, Кризисов: 63
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:06 | Осталось: 0:03:13
# Эпизод 78/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:07 | Осталось: 0:03:12
# Эпизод 79/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 97.88, Кризисов: 50
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:01:08 | Осталось: 0:03:12
# Эпизод 80/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 90.04, Кризисов: 58
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:09 | Осталось: 0:03:11
# Эпизод 81/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.14, Кризисов: 63
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:10 | Осталось: 0:03:10
# Эпизод 82/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 97.88, Кризисов: 50
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:11 | Осталось: 0:03:09
# Эпизод 83/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 91.02, Кризисов: 57
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:12 | Осталось: 0:03:08
# Эпизод 84/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.00, Кризисов: 56
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:12 | Осталось: 0:03:07
# Эпизод 85/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 93.96, Кризисов: 54
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:13 | Осталось: 0:03:06
# Эпизод 86/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 76.31, Кризисов: 72
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:14 | Осталось: 0:03:05
# Эпизод 87/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:15 | Осталось: 0:03:04
# Эпизод 88/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 86.12, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:16 | Осталось: 0:03:03
# Эпизод 89/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 82.20, Кризисов: 66
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:17 | Осталось: 0:03:02
# Эпизод 90/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.00, Кризисов: 56
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:17 | Осталось: 0:03:01
#   Промежуточные результаты сохранены на эпохе 90
# Эпизод 91/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 81.22, Кризисов: 67
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:18 | Осталось: 0:03:00
# Эпизод 92/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 87.10, Кризисов: 61
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:19 | Осталось: 0:02:59
# Эпизод 93/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:01:20 | Осталось: 0:02:59
# Эпизод 94/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 111.61, Кризисов: 36
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:21 | Осталось: 0:02:58
# Эпизод 95/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 89.06, Кризисов: 59
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:22 | Осталось: 0:02:57
# Эпизод 96/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 78.28, Кризисов: 70
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:23 | Осталось: 0:02:56
# Эпизод 97/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 83.18, Кризисов: 65
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:23 | Осталось: 0:02:55
# Эпизод 98/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 70.43, Кризисов: 78
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:24 | Осталось: 0:02:54
# Эпизод 99/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 101.80, Кризисов: 46
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:25 | Осталось: 0:02:53
# Эпизод 100/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 83.18, Кризисов: 65
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:25 | Осталось: 0:02:51
# Эпизод 101/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.00, Кризисов: 56
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:26 | Осталось: 0:02:50
# Эпизод 102/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 83.18, Кризисов: 65
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:27 | Осталось: 0:02:50
# Эпизод 103/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 65.53, Кризисов: 83
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:28 | Осталось: 0:02:49
# Эпизод 104/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 87.10, Кризисов: 61
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:29 | Осталось: 0:02:48
# Эпизод 105/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 90.04, Кризисов: 58
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:30 | Осталось: 0:02:47
# Эпизод 106/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 80.24, Кризисов: 68
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:31 | Осталось: 0:02:46
# Эпизод 107/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.00, Кризисов: 56
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:01:32 | Осталось: 0:02:46
# Эпизод 108/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 87.10, Кризисов: 61
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:33 | Осталось: 0:02:45
# Эпизод 109/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:33 | Осталось: 0:02:44
# Эпизод 110/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 91.02, Кризисов: 57
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:34 | Осталось: 0:02:43
# Эпизод 111/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 94.94, Кризисов: 53
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:35 | Осталось: 0:02:42
# Эпизод 112/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 82.20, Кризисов: 66
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:36 | Осталось: 0:02:41
# Эпизод 113/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:37 | Осталось: 0:02:40
# Эпизод 114/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 86.12, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:38 | Осталось: 0:02:39
# Эпизод 115/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 102.79, Кризисов: 45
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:38 | Осталось: 0:02:38
# Эпизод 116/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 96.90, Кризисов: 51
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:39 | Осталось: 0:02:38
# Эпизод 117/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 91.02, Кризисов: 57
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:40 | Осталось: 0:02:37
# Эпизод 118/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 95.92, Кризисов: 52
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:41 | Осталось: 0:02:36
# Эпизод 119/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 80.24, Кризисов: 68
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:42 | Осталось: 0:02:35
# Эпизод 120/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 80.24, Кризисов: 68
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:01:43 | Осталось: 0:02:34
#   Промежуточные результаты сохранены на эпохе 120
# Эпизод 121/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 70.43, Кризисов: 78
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:01:44 | Осталось: 0:02:34
# Эпизод 122/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 101.80, Кризисов: 46
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:45 | Осталось: 0:02:33
# Эпизод 123/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 99.84, Кризисов: 48
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:45 | Осталось: 0:02:32
# Эпизод 124/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 86.12, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:46 | Осталось: 0:02:31
# Эпизод 125/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 102.79, Кризисов: 45
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:47 | Осталось: 0:02:30
# Эпизод 126/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.14, Кризисов: 63
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:48 | Осталось: 0:02:29
# Эпизод 127/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 87.10, Кризисов: 61
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:48 | Осталось: 0:02:28
# Эпизод 128/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.98, Кризисов: 55
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:49 | Осталось: 0:02:27
# Эпизод 129/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.00, Кризисов: 56
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:50 | Осталось: 0:02:26
# Эпизод 130/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 93.96, Кризисов: 54
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:51 | Осталось: 0:02:25
# Эпизод 131/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.00, Кризисов: 56
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:51 | Осталось: 0:02:24
# Эпизод 132/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 90.04, Кризисов: 58
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:52 | Осталось: 0:02:23
# Эпизод 133/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 90.04, Кризисов: 58
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:53 | Осталось: 0:02:22
# Эпизод 134/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.14, Кризисов: 63
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:54 | Осталось: 0:02:21
# Эпизод 135/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 93.96, Кризисов: 54
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:01:55 | Осталось: 0:02:21
# Эпизод 136/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.98, Кризисов: 55
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:56 | Осталось: 0:02:20
# Эпизод 137/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 80.24, Кризисов: 68
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:57 | Осталось: 0:02:19
# Эпизод 138/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.98, Кризисов: 55
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:57 | Осталось: 0:02:18
# Эпизод 139/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 81.22, Кризисов: 67
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:58 | Осталось: 0:02:17
# Эпизод 140/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:01:59 | Осталось: 0:02:16
# Эпизод 141/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.14, Кризисов: 63
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:00 | Осталось: 0:02:15
# Эпизод 142/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 89.06, Кризисов: 59
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:00 | Осталось: 0:02:14
# Эпизод 143/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.14, Кризисов: 63
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:01 | Осталось: 0:02:13
# Эпизод 144/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 90.04, Кризисов: 58
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:02 | Осталось: 0:02:12
# Эпизод 145/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 95.92, Кризисов: 52
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:03 | Осталось: 0:02:11
# Эпизод 146/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:04 | Осталось: 0:02:10
# Эпизод 147/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:04 | Осталось: 0:02:10
# Эпизод 148/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 97.88, Кризисов: 50
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:02:05 | Осталось: 0:02:09
# Эпизод 149/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 89.06, Кризисов: 59
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:02:07 | Осталось: 0:02:08
# Эпизод 150/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 97.88, Кризисов: 50
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:08 | Осталось: 0:02:08
#   Промежуточные результаты сохранены на эпохе 150
# Эпизод 151/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 84.16, Кризисов: 64
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:08 | Осталось: 0:02:07
# Эпизод 152/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 84.16, Кризисов: 64
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:09 | Осталось: 0:02:06
# Эпизод 153/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 83.18, Кризисов: 65
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:10 | Осталось: 0:02:05
# Эпизод 154/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 94.94, Кризисов: 53
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:11 | Осталось: 0:02:04
# Эпизод 155/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 84.16, Кризисов: 64
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:12 | Осталось: 0:02:03
# Эпизод 156/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 96.90, Кризисов: 51
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:12 | Осталось: 0:02:02
# Эпизод 157/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 94.94, Кризисов: 53
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:13 | Осталось: 0:02:01
# Эпизод 158/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 96.90, Кризисов: 51
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:14 | Осталось: 0:02:00
# Эпизод 159/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 96.90, Кризисов: 51
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:15 | Осталось: 0:01:59
# Эпизод 160/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 77.29, Кризисов: 71
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:16 | Осталось: 0:01:59
# Эпизод 161/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 82.20, Кризисов: 66
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:16 | Осталось: 0:01:58
# Эпизод 162/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 87.10, Кризисов: 61
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:02:17 | Осталось: 0:01:57
# Эпизод 163/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 102.79, Кризисов: 45
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:18 | Осталось: 0:01:56
# Эпизод 164/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 111.61, Кризисов: 36
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:19 | Осталось: 0:01:55
# Эпизод 165/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 84.16, Кризисов: 64
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:20 | Осталось: 0:01:54
# Эпизод 166/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 80.24, Кризисов: 68
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:21 | Осталось: 0:01:54
# Эпизод 167/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.98, Кризисов: 55
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:22 | Осталось: 0:01:53
# Эпизод 168/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 94.94, Кризисов: 53
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:22 | Осталось: 0:01:52
# Эпизод 169/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 93.96, Кризисов: 54
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:23 | Осталось: 0:01:51
# Эпизод 170/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.00, Кризисов: 56
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:24 | Осталось: 0:01:50
# Эпизод 171/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 75.33, Кризисов: 73
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:25 | Осталось: 0:01:49
# Эпизод 172/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 75.33, Кризисов: 73
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:25 | Осталось: 0:01:48
# Эпизод 173/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 99.84, Кризисов: 48
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:26 | Осталось: 0:01:47
# Эпизод 174/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 86.12, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:27 | Осталось: 0:01:46
# Эпизод 175/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 90.04, Кризисов: 58
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:27 | Осталось: 0:01:45
# Эпизод 176/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 83.18, Кризисов: 65
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:28 | Осталось: 0:01:44
# Эпизод 177/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.98, Кризисов: 55
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:02:29 | Осталось: 0:01:44
# Эпизод 178/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.14, Кризисов: 63
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:30 | Осталось: 0:01:43
# Эпизод 179/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.00, Кризисов: 56
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:31 | Осталось: 0:01:42
# Эпизод 180/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 95.92, Кризисов: 52
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:32 | Осталось: 0:01:41
#   Промежуточные результаты сохранены на эпохе 180
# Эпизод 181/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 83.18, Кризисов: 65
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:33 | Осталось: 0:01:40
# Эпизод 182/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 84.16, Кризисов: 64
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:33 | Осталось: 0:01:39
# Эпизод 183/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.98, Кризисов: 55
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:34 | Осталось: 0:01:38
# Эпизод 184/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 82.20, Кризисов: 66
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:35 | Осталось: 0:01:37
# Эпизод 185/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:36 | Осталось: 0:01:37
# Эпизод 186/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 83.18, Кризисов: 65
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:36 | Осталось: 0:01:36
# Эпизод 187/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.98, Кризисов: 55
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:37 | Осталось: 0:01:35
# Эпизод 188/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 80.24, Кризисов: 68
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:38 | Осталось: 0:01:34
# Эпизод 189/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 86.12, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:02:39 | Осталось: 0:01:33
# Эпизод 190/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
# ...
#   Средняя награда: 98.86, Кризисов: 49
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:22 | Осталось: 0:00:50
#   Промежуточные результаты сохранены на эпохе 240
# Эпизод 241/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 91.02, Кризисов: 57
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:22 | Осталось: 0:00:49
# Эпизод 242/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.98, Кризисов: 55
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:23 | Осталось: 0:00:48
# Эпизод 243/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 86.12, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:24 | Осталось: 0:00:47
# Эпизод 244/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 78.28, Кризисов: 70
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:25 | Осталось: 0:00:47
# Эпизод 245/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 91.02, Кризисов: 57
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:25 | Осталось: 0:00:46
# Эпизод 246/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 93.96, Кризисов: 54
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:03:27 | Осталось: 0:00:45
# Эпизод 247/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 90.04, Кризисов: 58
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:03:28 | Осталось: 0:00:44
# Эпизод 248/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 103.77, Кризисов: 44
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:28 | Осталось: 0:00:43
# Эпизод 249/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 89.06, Кризисов: 59
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:29 | Осталось: 0:00:42
# Эпизод 250/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 90.04, Кризисов: 58
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:30 | Осталось: 0:00:42
# Эпизод 251/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 93.96, Кризисов: 54
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:31 | Осталось: 0:00:41
# Эпизод 252/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 91.02, Кризисов: 57
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:32 | Осталось: 0:00:40
# Эпизод 253/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 96.90, Кризисов: 51
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:32 | Осталось: 0:00:39
# Эпизод 254/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 87.10, Кризисов: 61
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:33 | Осталось: 0:00:38
# Эпизод 255/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 91.02, Кризисов: 57
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:34 | Осталось: 0:00:37
# Эпизод 256/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 93.96, Кризисов: 54
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:35 | Осталось: 0:00:36
# Эпизод 257/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 97.88, Кризисов: 50
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:36 | Осталось: 0:00:36
# Эпизод 258/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 102.79, Кризисов: 45
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:36 | Осталось: 0:00:35
# Эпизод 259/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 86.12, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:37 | Осталось: 0:00:34
# Эпизод 260/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:03:38 | Осталось: 0:00:33
# Эпизод 261/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 94.94, Кризисов: 53
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:03:39 | Осталось: 0:00:32
# Эпизод 262/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.00, Кризисов: 56
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:40 | Осталось: 0:00:31
# Эпизод 263/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 89.06, Кризисов: 59
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:41 | Осталось: 0:00:31
# Эпизод 264/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 91.02, Кризисов: 57
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:42 | Осталось: 0:00:30
# Эпизод 265/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 89.06, Кризисов: 59
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:43 | Осталось: 0:00:29
# Эпизод 266/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 89.06, Кризисов: 59
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:43 | Осталось: 0:00:28
# Эпизод 267/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.98, Кризисов: 55
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:44 | Осталось: 0:00:27
# Эпизод 268/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 80.24, Кризисов: 68
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:45 | Осталось: 0:00:26
# Эпизод 269/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.14, Кризисов: 63
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:46 | Осталось: 0:00:26
# Эпизод 270/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 97.88, Кризисов: 50
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:47 | Осталось: 0:00:25
#   Промежуточные результаты сохранены на эпохе 270
# Эпизод 271/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 94.94, Кризисов: 53
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:48 | Осталось: 0:00:24
# Эпизод 272/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 86.12, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:48 | Осталось: 0:00:23
# Эпизод 273/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 101.80, Кризисов: 46
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:03:49 | Осталось: 0:00:22
# Эпизод 274/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.98, Кризисов: 55
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:03:51 | Осталось: 0:00:21
# Эпизод 275/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.14, Кризисов: 63
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:51 | Осталось: 0:00:21
# Эпизод 276/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 79.26, Кризисов: 69
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:52 | Осталось: 0:00:20
# Эпизод 277/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 86.12, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:53 | Осталось: 0:00:19
# Эпизод 278/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 100.82, Кризисов: 47
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:54 | Осталось: 0:00:18
# Эпизод 279/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 87.10, Кризисов: 61
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:55 | Осталось: 0:00:17
# Эпизод 280/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 90.04, Кризисов: 58
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:55 | Осталось: 0:00:16
# Эпизод 281/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 86.12, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:56 | Осталось: 0:00:16
# Эпизод 282/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 95.92, Кризисов: 52
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:57 | Осталось: 0:00:15
# Эпизод 283/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 90.04, Кризисов: 58
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:58 | Осталось: 0:00:14
# Эпизод 284/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 87.10, Кризисов: 61
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:58 | Осталось: 0:00:13
# Эпизод 285/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:03:59 | Осталось: 0:00:12
# Эпизод 286/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 79.26, Кризисов: 69
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:04:00 | Осталось: 0:00:11
# Эпизод 287/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 84.16, Кризисов: 64
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:04:01 | Осталось: 0:00:10
# Эпизод 288/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 89.06, Кризисов: 59
#   Время эпизода: 0:00:01
#   Прошло эксперимента: 0:04:02 | Осталось: 0:00:10
# Эпизод 289/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 85.14, Кризисов: 63
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:04:03 | Осталось: 0:00:09
# Эпизод 290/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 99.84, Кризисов: 48
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:04:04 | Осталось: 0:00:08
# Эпизод 291/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:04:05 | Осталось: 0:00:07
# Эпизод 292/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 89.06, Кризисов: 59
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:04:05 | Осталось: 0:00:06
# Эпизод 293/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 86.12, Кризисов: 62
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:04:06 | Осталось: 0:00:05
# Эпизод 294/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 90.04, Кризисов: 58
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:04:07 | Осталось: 0:00:05
# Эпизод 295/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 91.02, Кризисов: 57
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:04:08 | Осталось: 0:00:04
# Эпизод 296/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 92.00, Кризисов: 56
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:04:08 | Осталось: 0:00:03
# Эпизод 297/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 101.80, Кризисов: 46
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:04:09 | Осталось: 0:00:02
# Эпизод 298/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 88.08, Кризисов: 60
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:04:10 | Осталось: 0:00:01
# Эпизод 299/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 82.20, Кризисов: 66
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:04:11 | Осталось: 0:00:00
# Эпизод 300/300
#   Шаг 17/51 (33.3%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Шаг 34/51 (66.7%) | Прошло: 0:00:00 | Осталось: 0:00:00
#   Средняя награда: 87.10, Кризисов: 61
#   Время эпизода: 0:00:00
#   Прошло эксперимента: 0:04:12 | Осталось: 0:00:00
#   Промежуточные результаты сохранены на эпохе 300
# Эксперимент с MAPPO завершен.
# Общее время эксперимента: 0:04:12
# === ИТОГОВАЯ СВОДКА ДЛЯ MAPPO ===
# Средняя награда по всем эпизодам: 88.27 ± 7.53
# Общее количество кризисов: 17904
# Общее количество переходов между стадиями: 6900
#
# Топ-5 типов кризисов по частоте:
#   Пандемия: 2301 раз
#   Политический переворот: 2282 раз
#   Технологическая катастрофа: 2249 раз
#   Военный конфликт: 2244 раз
#   Социальные волнения: 2228 раз
#
# Распределение кризисов по странам:
#   Spain: 3413 кризисов
#   South Korea: 806 кризисов
#   China: 802 кризисов
#   Russia: 788 кризисов
#   Germany: 786 кризисов
#   Italy: 772 кризисов
#   Netherlands: 772 кризисов
#   Saudi Arabia: 766 кризисов
#   United States: 760 кризисов
#   France: 758 кризисов
#   Canada: 757 кризисов
#   Japan: 756 кризисов
#   India: 754 кризисов
#   United Kingdom: 753 кризисов
#   Australia: 753 кризисов
#   Indonesia: 749 кризисов
#   Brazil: 748 кризисов
#   Mexico: 740 кризисов
#   Turkey: 740 кризисов
#   Switzerland: 731 кризисов

# %%
# =============================================================================
# БЛОК 3: СРАВНИТЕЛЬНЫЙ АНАЛИЗ РЕЗУЛЬТАТОВ УЛУЧШЕННЫХ ЭКСПЕРИМЕНТОВ (300 ЭПОХ)
# =============================================================================

import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import os

CONFIG = {
    'maddpg_save_dir': 'experiment_results_maddpg_improved_300ep',
    'mappo_save_dir': 'experiment_results_mappo_improved_300ep',
    'comparison_dir': 'experiment_comparison_improved_300ep',
    'device': 'cpu'
}

os.makedirs(CONFIG['comparison_dir'], exist_ok=True)

def load_results():
    """Загрузка результатов экспериментов"""
    try:
        with open(f"{CONFIG['maddpg_save_dir']}/MADDPG_results.pkl", 'rb') as f:
            maddpg_results = pickle.load(f)
        print("Результаты MADDPG успешно загружены.")
    except FileNotFoundError:
        print("Файл результатов MADDPG не найден.")
        maddpg_results = None

    try:
        with open(f"{CONFIG['mappo_save_dir']}/MAPPO_results.pkl", 'rb') as f:
            mappo_results = pickle.load(f)
        print("Результаты MAPPO успешно загружены.")
    except FileNotFoundError:
        print("Файл результатов MAPPO не найден.")
        mappo_results = None

    return maddpg_results, mappo_results

def compare_rewards(maddpg_results, mappo_results):
    """Сравнение наград"""
    if maddpg_results is None or mappo_results is None:
        print("Невозможно сравнить награды: отсутствуют результаты одного или обоих экспериментов.")
        return

    fig, axes = plt.subplots(2, 2, figsize=(15, 10))

    # График наград по эпизодам
    axes[0, 0].plot(maddpg_results['all_rewards'], label='MADDPG', alpha=0.7, linewidth=2, color='blue')
    axes[0, 0].plot(mappo_results['all_rewards'], label='MAPPO', alpha=0.7, linewidth=2, color='red')
    axes[0, 0].set_xlabel('Эпизод')
    axes[0, 0].set_ylabel('Средняя награда')
    axes[0, 0].set_title('Сравнение средних наград по эпизодам')
    axes[0, 0].legend()
    axes[0, 0].grid(True)

    # Скользящее среднее наград
    window_size = 20
    maddpg_rewards_smooth = pd.Series(maddpg_results['all_rewards']).rolling(window=window_size).mean()
    mappo_rewards_smooth = pd.Series(mappo_results['all_rewards']).rolling(window=window_size).mean()

    axes[0, 1].plot(maddpg_rewards_smooth, label='MADDPG (скользящее среднее)', alpha=0.7, linewidth=2, color='blue')
    axes[0, 1].plot(mappo_rewards_smooth, label='MAPPO (скользящее среднее)', alpha=0.7, linewidth=2, color='red')
    axes[0, 1].set_xlabel('Эпизод')
    axes[0, 1].set_ylabel('Средняя награда')
    axes[0, 1].set_title(f'Сравнение скользящего среднего наград (окно={window_size})')
    axes[0, 1].legend()
    axes[0, 1].grid(True)

    # Гистограмма распределения наград
    axes[1, 0].hist(maddpg_results['all_rewards'], bins=20, alpha=0.7, label='MADDPG', color='blue')
    axes[1, 0].hist(mappo_results['all_rewards'], bins=20, alpha=0.7, label='MAPPO', color='red')
    axes[1, 0].set_xlabel('Награда')
    axes[1, 0].set_ylabel('Частота')
    axes[1, 0].set_title('Распределение наград')
    axes[1, 0].legend()
    axes[1, 0].grid(True)

    # Boxplot наград
    rewards_data = [maddpg_results['all_rewards'], mappo_results['all_rewards']]
    axes[1, 1].boxplot(rewards_data, labels=['MADDPG', 'MAPPO'])
    axes[1, 1].set_ylabel('Награда')
    axes[1, 1].set_title('Boxplot распределения наград')
    axes[1, 1].grid(True)

    plt.tight_layout()
    plt.savefig(f"{CONFIG['comparison_dir']}/reward_comparison_detailed.png", dpi=300, bbox_inches='tight')
    plt.show()

    # Статистика
    maddpg_avg = np.mean(maddpg_results['all_rewards'])
    mappo_avg = np.mean(mappo_results['all_rewards'])
    maddpg_std = np.std(maddpg_results['all_rewards'])
    mappo_std = np.std(mappo_results['all_rewards'])

    print("\n=== СРАВНЕНИЕ НАГРАД ===")
    print(f"MADDPG - Средняя награда: {maddpg_avg:.2f} ± {maddpg_std:.2f}")
    print(f"MAPPO - Средняя награда: {mappo_avg:.2f} ± {mappo_std:.2f}")
    print(f"Разница: {mappo_avg - maddpg_avg:.2f}")

def compare_crises(maddpg_results, mappo_results):
    """Сравнение кризисов"""
    if maddpg_results is None or mappo_results is None:
        print("Невозможно сравнить кризисы: отсутствуют результаты одного или обоих экспериментов.")
        return

    # Общее количество кризисов
    maddpg_total_crises = sum(len(crises) for crises in maddpg_results['all_crisis_histories'].values())
    mappo_total_crises = sum(len(crises) for crises in mappo_results['all_crisis_histories'].values())

    print("\n=== СРАВНЕНИЕ КРИЗИСОВ ===")
    print(f"Общее количество кризисов MADDPG: {maddpg_total_crises}")
    print(f"Общее количество кризисов MAPPO: {mappo_total_crises}")

    # Типы кризисов
    maddpg_crisis_types = []
    for crises in maddpg_results['all_crisis_histories'].values():
        for crisis in crises:
            maddpg_crisis_types.append(crisis['crisis'])

    mappo_crisis_types = []
    for crises in mappo_results['all_crisis_histories'].values():
        for crisis in crises:
            mappo_crisis_types.append(crisis['crisis'])

    from collections import Counter
    maddpg_counter = Counter(maddpg_crisis_types)
    mappo_counter = Counter(mappo_crisis_types)

    print("\nТоп-5 типов кризисов MADDPG:")
    for crisis, count in maddpg_counter.most_common(5):
        print(f"  {crisis}: {count} раз")

    print("\nТоп-5 типов кризисов MAPPO:")
    for crisis, count in mappo_counter.most_common(5):
        print(f"  {crisis}: {count} раз")

def compare_stage_transitions(maddpg_results, mappo_results):
    """Сравнение переходов между стадиями"""
    if maddpg_results is None or mappo_results is None:
        print("Невозможно сравнить переходы: отсутствуют результаты одного или обоих экспериментов.")
        return

    maddpg_total_transitions = sum(len(transitions) for transitions in maddpg_results['all_stage_transitions'].values())
    mappo_total_transitions = sum(len(transitions) for transitions in mappo_results['all_stage_transitions'].values())

    print("\n=== СРАВНЕНИЕ ПЕРЕХОДОВ МЕЖДУ СТАДИЯМИ ===")
    print(f"Общее количество переходов MADDPG: {maddpg_total_transitions}")
    print(f"Общее количество переходов MAPPO: {mappo_total_transitions}")

def compare_countries_detailed(maddpg_results, mappo_results):
    """Подробное сравнение результатов по странам"""
    if maddpg_results is None or mappo_results is None:
        print("Невозможно сравнить страны: отсутствуют результаты одного или обоих экспериментов.")
        return

    countries = maddpg_results['countries'] if maddpg_results else mappo_results['countries']

    print("\n=== СРАВНЕНИЕ РЕЗУЛЬТАТОВ ПО СТРАНАМ ===")

    comparison_data = []

    for country in countries:
        maddpg_crises = len(maddpg_results['all_crisis_histories'][country]) if country in maddpg_results['all_crisis_histories'] else 0
        mappo_crises = len(mappo_results['all_crisis_histories'][country]) if country in mappo_results['all_crisis_histories'] else 0

        maddpg_transitions = len(maddpg_results['all_stage_transitions'][country]) if country in maddpg_results['all_stage_transitions'] else 0
        mappo_transitions = len(mappo_results['all_stage_transitions'][country]) if country in mappo_results['all_stage_transitions'] else 0

        comparison_data.append({
            'Страна': country,
            'MADDPG кризисы': maddpg_crises,
            'MAPPO кризисы': mappo_crises,
            'MADDPG переходы': maddpg_transitions,
            'MAPPO переходы': mappo_transitions
        })

    df = pd.DataFrame(comparison_data)
    print(df.to_string(index=False))

    # Создание графиков сравнения по странам
    fig, axes = plt.subplots(2, 2, figsize=(18, 12))

    # Сравнение кризисов по странам
    x_pos = np.arange(len(countries))
    width = 0.35

    maddpg_crises = [len(maddpg_results['all_crisis_histories'][country]) if country in maddpg_results['all_crisis_histories'] else 0 for country in countries]
    mappo_crises = [len(mappo_results['all_crisis_histories'][country]) if country in mappo_results['all_crisis_histories'] else 0 for country in countries]

    axes[0, 0].bar(x_pos - width/2, maddpg_crises, width, label='MADDPG', alpha=0.7, color='blue')
    axes[0, 0].bar(x_pos + width/2, mappo_crises, width, label='MAPPO', alpha=0.7, color='red')
    axes[0, 0].set_xlabel('Страны')
    axes[0, 0].set_ylabel('Количество кризисов')
    axes[0, 0].set_title('Сравнение количества кризисов по странам')
    axes[0, 0].set_xticks(x_pos)
    axes[0, 0].set_xticklabels(countries, rotation=45, ha='right')
    axes[0, 0].legend()
    axes[0, 0].grid(True)

    # Сравнение переходов по странам
    maddpg_transitions = [len(maddpg_results['all_stage_transitions'][country]) if country in maddpg_results['all_stage_transitions'] else 0 for country in countries]
    mappo_transitions = [len(mappo_results['all_stage_transitions'][country]) if country in mappo_results['all_stage_transitions'] else 0 for country in countries]

    axes[0, 1].bar(x_pos - width/2, maddpg_transitions, width, label='MADDPG', alpha=0.7, color='blue')
    axes[0, 1].bar(x_pos + width/2, mappo_transitions, width, label='MAPPO', alpha=0.7, color='red')
    axes[0, 1].set_xlabel('Страны')
    axes[0, 1].set_ylabel('Количество переходов')
    axes[0, 1].set_title('Сравнение количества переходов по странам')
    axes[0, 1].set_xticks(x_pos)
    axes[0, 1].set_xticklabels(countries, rotation=45, ha='right')
    axes[0, 1].legend()
    axes[0, 1].grid(True)

    # Тепловая карта кризисов
    crisis_matrix = np.array([maddpg_crises, mappo_crises])
    im = axes[1, 0].imshow(crisis_matrix, cmap='Reds', aspect='auto')
    axes[1, 0].set_xticks(np.arange(len(countries)))
    axes[1, 0].set_yticks(np.arange(2))
    axes[1, 0].set_xticklabels(countries, rotation=45, ha='right')
    axes[1, 0].set_yticklabels(['MADDPG', 'MAPPO'])
    axes[1, 0].set_title('Тепловая карта кризисов по странам')
    plt.colorbar(im, ax=axes[1, 0])

    # Тепловая карта переходов
    transition_matrix = np.array([maddpg_transitions, mappo_transitions])
    im = axes[1, 1].imshow(transition_matrix, cmap='Blues', aspect='auto')
    axes[1, 1].set_xticks(np.arange(len(countries)))
    axes[1, 1].set_yticks(np.arange(2))
    axes[1, 1].set_xticklabels(countries, rotation=45, ha='right')
    axes[1, 1].set_yticklabels(['MADDPG', 'MAPPO'])
    axes[1, 1].set_title('Тепловая карта переходов по странам')
    plt.colorbar(im, ax=axes[1, 1])

    plt.tight_layout()
    plt.savefig(f"{CONFIG['comparison_dir']}/country_comparison_detailed.png", dpi=300, bbox_inches='tight')
    plt.show()

    # Сохранение в файл
    df.to_csv(f"{CONFIG['comparison_dir']}/country_comparison.csv", index=False, encoding='utf-8')
    print(f"\nСравнение по странам сохранено в {CONFIG['comparison_dir']}/country_comparison.csv")

def create_summary_report(maddpg_results, mappo_results):
    """Создание сводного отчета"""
    with open(f"{CONFIG['comparison_dir']}/summary_report.txt", 'w', encoding='utf-8') as f:
        f.write("СВОДНЫЙ ОТЧЕТ СРАВНЕНИЯ УЛУЧШЕННЫХ MADDPG И MAPPO (300 ЭПОХ)\n")
        f.write("=" * 60 + "\n")
        f.write(f"Дата создания отчета: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n\n")

        if maddpg_results and mappo_results:
            maddpg_avg = np.mean(maddpg_results['all_rewards'])
            mappo_avg = np.mean(mappo_results['all_rewards'])
            maddpg_std = np.std(maddpg_results['all_rewards'])
            mappo_std = np.std(mappo_results['all_rewards'])
            maddpg_total_crises = sum(len(crises) for crises in maddpg_results['all_crisis_histories'].values())
            mappo_total_crises = sum(len(crises) for crises in mappo_results['all_crisis_histories'].values())
            maddpg_total_transitions = sum(len(transitions) for transitions in maddpg_results['all_stage_transitions'].values())
            mappo_total_transitions = sum(len(transitions) for transitions in mappo_results['all_stage_transitions'].values())

            f.write("ОСНОВНЫЕ ПОКАЗАТЕЛИ:\n")
            f.write(f"MADDPG - Средняя награда: {maddpg_avg:.2f} ± {maddpg_std:.2f}\n")
            f.write(f"MAPPO - Средняя награда: {mappo_avg:.2f} ± {mappo_std:.2f}\n")
            f.write(f"MADDPG - Общее количество кризисов: {maddpg_total_crises}\n")
            f.write(f"MAPPO - Общее количество кризисов: {mappo_total_crises}\n")
            f.write(f"MADDPG - Общее количество переходов: {maddpg_total_transitions}\n")
            f.write(f"MAPPO - Общее количество переходов: {mappo_total_transitions}\n")

            winner = "MAPPO" if mappo_avg > maddpg_avg else "MADDPG" if maddpg_avg > mappo_avg else "Ничья"
            f.write(f"\nПОБЕДИТЕЛЬ ПО СРЕДНЕЙ НАГРАДЕ: {winner}\n")

            # Анализ эффективности
            if mappo_total_crises < maddpg_total_crises:
                f.write("MAPPO показал лучшую стабильность (меньше кризисов)\n")
            elif maddpg_total_crises < mappo_total_crises:
                f.write("MADDPG показал лучшую стабильность (меньше кризисов)\n")
            else:
                f.write("Оба алгоритма показали одинаковую стабильность\n")

            if mappo_total_transitions > maddpg_total_transitions:
                f.write("MAPPO показал большую адаптивность (больше переходов)\n")
            elif maddpg_total_transitions > mappo_total_transitions:
                f.write("MADDPG показал большую адаптивность (больше переходов)\n")
            else:
                f.write("Оба алгоритма показали одинаковую адаптивность\n")
        else:
            f.write("Недостаточно данных для сравнения.\n")

    print(f"\nСводный отчет сохранен в {CONFIG['comparison_dir']}/summary_report.txt")

def analyze_learning_curves(maddpg_results, mappo_results):
    """Анализ кривых обучения"""
    if maddpg_results is None or mappo_results is None:
        print("Невозможно проанализировать кривые обучения.")
        return

    # Определение стабильности обучения
    maddpg_rewards = np.array(maddpg_results['all_rewards'])
    mappo_rewards = np.array(mappo_results['all_rewards'])

    # Вычисление коэффициента вариации (меньше = стабильнее)
    maddpg_cv = np.std(maddpg_rewards) / np.mean(maddpg_rewards) if np.mean(maddpg_rewards) != 0 else float('inf')
    mappo_cv = np.std(mappo_rewards) / np.mean(mappo_rewards) if np.mean(mappo_rewards) != 0 else float('inf')

    # Вычисление тренда (наклон линейной регрессии)
    from scipy.stats import linregress
    maddpg_slope = linregress(range(len(maddpg_rewards)), maddpg_rewards).slope
    mappo_slope = linregress(range(len(mappo_rewards)), mappo_rewards).slope

    print("\n=== АНАЛИЗ КРИВЫХ ОБУЧЕНИЯ ===")
    print(f"MADDPG - Коэффициент вариации: {maddpg_cv:.4f}")
    print(f"MAPPO - Коэффициент вариации: {mappo_cv:.4f}")
    print(f"MADDPG - Наклон тренда: {maddpg_slope:.4f}")
    print(f"MAPPO - Наклон тренда: {mappo_slope:.4f}")

    if maddpg_cv < mappo_cv:
        print("MADDPG показал более стабильное обучение")
    else:
        print("MAPPO показал более стабильное обучение")

    if maddpg_slope > mappo_slope:
        print("MADDPG показал более высокий темп обучения")
    else:
        print("MAPPO показал более высокий темп обучения")

def prevent_runtime_disconnect():
    print("Для предотвращения отключения среды введите '555' и нажмите Enter:")
    while True:
        user_input = input()
        if user_input == "555":
            print("Среда защищена от отключения.")
            break
        else:
            print("Неверный код. Пожалуйста, введите '555':")

def main():
    """Основная функция сравнения"""
    prevent_runtime_disconnect()

    print("ЗАГРУЗКА РЕЗУЛЬТАТОВ УЛУЧШЕННЫХ ЭКСПЕРИМЕНТОВ (300 ЭПОХ)")
    print("=" * 50)

    maddpg_results, mappo_results = load_results()

    if maddpg_results is None and mappo_results is None:
        print("Нет результатов для сравнения.")
        return

    print("\nСРАВНЕНИЕ РЕЗУЛЬТАТОВ")
    print("=" * 50)

    # Сравнение наград
    compare_rewards(maddpg_results, mappo_results)

    # Сравнение кризисов
    compare_crises(maddpg_results, mappo_results)

    # Сравнение переходов
    compare_stage_transitions(maddpg_results, mappo_results)

    # Сравнение по странам
    compare_countries_detailed(maddpg_results, mappo_results)

    # Анализ кривых обучения
    analyze_learning_curves(maddpg_results, mappo_results)

    # Создание сводного отчета
    create_summary_report(maddpg_results, mappo_results)

    print(f"\nСРАВНЕНИЕ ЗАВЕРШЕНО!")
    print(f"Результаты сохранены в директории: {CONFIG['comparison_dir']}")

if __name__ == "__main__":
    main()
# Out:
# Для предотвращения отключения среды введите '555' и нажмите Enter:
# 555
# Среда защищена от отключения.
# ЗАГРУЗКА РЕЗУЛЬТАТОВ УЛУЧШЕННЫХ ЭКСПЕРИМЕНТОВ (300 ЭПОХ)
# ==================================================
# Результаты MADDPG успешно загружены.
# Результаты MAPPO успешно загружены.
#
# СРАВНЕНИЕ РЕЗУЛЬТАТОВ
# ==================================================
# === СРАВНЕНИЕ НАГРАД ===
# MADDPG - Средняя награда: 80.64 ± 7.12
# MAPPO - Средняя награда: 88.27 ± 7.53
# Разница: 7.63
#
# === СРАВНЕНИЕ КРИЗИСОВ ===
# Общее количество кризисов MADDPG: 16833
# Общее количество кризисов MAPPO: 17904
#
# Топ-5 типов кризисов MADDPG:
#   Социальные волнения: 2170 раз
#   Пандемия: 2161 раз
#   Политический переворот: 2144 раз
#   Экономический кризис: 2098 раз
#   Экологическая катастрофа: 2079 раз
#
# Топ-5 типов кризисов MAPPO:
#   Пандемия: 2301 раз
#   Политический переворот: 2282 раз
#   Технологическая катастрофа: 2249 раз
#   Военный конфликт: 2244 раз
#   Социальные волнения: 2228 раз
#
# === СРАВНЕНИЕ ПЕРЕХОДОВ МЕЖДУ СТАДИЯМИ ===
# Общее количество переходов MADDPG: 6935
# Общее количество переходов MAPPO: 6900
#
# === СРАВНЕНИЕ РЕЗУЛЬТАТОВ ПО СТРАНАМ ===
#         Страна  MADDPG кризисы  MAPPO кризисы  MADDPG переходы  MAPPO переходы
#  United States             767            760              606             300
#          China             762            802              300             300
#          Japan             745            756              300             300
#        Germany             756            786              300             300
#          India             789            754              300             300
# United Kingdom             796            753              301             600
#         France             777            758              300             300
#          Italy             763            772              608             300
#         Brazil             810            748              301             600
#         Canada             766            757              301             600
#    South Korea             780            806              300             300
#         Russia            2099            788              300             300
#      Australia             721            753              300             300
#          Spain             804           3413              300             300
#         Mexico             785            740              308             300
#      Indonesia             757            749              300             300
#    Netherlands             773            772              300             300
#   Saudi Arabia             810            766              602             300
#         Turkey             808            740              300             300
#    Switzerland             765            731              308             300
# Сравнение по странам сохранено в experiment_comparison_improved_300ep/country_comparison.csv
#
# === АНАЛИЗ КРИВЫХ ОБУЧЕНИЯ ===
# MADDPG - Коэффициент вариации: 0.0882
# MAPPO - Коэффициент вариации: 0.0853
# MADDPG - Наклон тренда: -0.0119
# MAPPO - Наклон тренда: 0.0154
# MAPPO показал более стабильное обучение
# MAPPO показал более высокий темп обучения
#
# Сводный отчет сохранен в experiment_comparison_improved_300ep/summary_report.txt
#
# СРАВНЕНИЕ ЗАВЕРШЕНО!
# Результаты сохранены в директории: experiment_comparison_improved_300ep
